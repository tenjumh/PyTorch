# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import torch.nn.functional as F
import random
import numpy as np
from collections import Counter, OrderedDict
import re
from copy import deepcopy
flatten = lambda l: [item for sublist in l for item in sublist]
random.seed(1024)

# %%
USE_CUDA = torch.cuda.is_available()
gpus = [0]
torch.cuda.set_device(gpus[0])

# %%
FloatTensor = torch.cuda.FloatTensor if USE_CUDA else torch.FloatTensor
LongTensor = torch.cuda.LongTensor if USE_CUDA else torch.LongTensor
ByteTensor = torch.cuda.ByteTensor if USE_CUDA else torch.ByteTensor

# %%
def getBatch(batch_size, train_data):
    random.shuffle(train_data)
    sindex = 0
    eindex = batch_size
    while eindex < len(train_data):
        batch = train_data[sindex: eindex]
        temp = eindex
        eindex = eindex + batch_size
        sindex = temp
        yield batch
    
    if eindex >= len(train_data):
        batch = train_data[sindex:]
        yield batch

# %%
def pad_to_batch(batch):
    x,y = zip(*batch)
    max_x = max([s.size(1) for s in x])
    x_p = []
    for i in range(len(batch)):
        if x[i].size(1) < max_x:
            x_p.append(torch.cat([x[i], Variable(LongTensor([word2index['<PAD>']] * (max_x - x[i].size(1)))).view(1, -1)], 1))
        else:
            x_p.append(x[i])
    return torch.cat(x_p), torch.cat(y).view(-1)

# %%
def prepare_sequence(seq, to_index):
    idxs = list(map(lambda w: to_index[w] if to_index.get(w) is not None else to_index["<UNK>"], seq))
    return Variable(LongTensor(idxs))

# %%
data = open('./data/train_1000.label.txt', 'r', encoding='latin-1').readlines()

# %%
data[:1]
# Out:
# ['DESC:manner How did serfdom develop in and then leave Russia ?\n']

# %%
data = [[d.split(':')[1][:-1], d.split(':')[0]] for d in data]

# %%
data
# Out:
# [['manner How did serfdom develop in and then leave Russia ?', 'DESC'],
#  ['cremat What films featured the character Popeye Doyle ?', 'ENTY'],
#  ["manner How can I find a list of celebrities ' real names ?", 'DESC'],
#  ['animal What fowl grabs the spotlight after the Chinese Year of the Monkey ?',
#   'ENTY'],
#  ['exp What is the full form of .com ?', 'ABBR'],
#  ['ind What contemptible scoundrel stole the cork from my lunch ?', 'HUM'],
#  ["gr What team did baseball 's St. Louis Browns become ?", 'HUM'],
#  ['title What is the oldest profession ?', 'HUM'],
#  ['def What are liver enzymes ?', 'DESC'],
#  ['ind Name the scar-faced bounty hunter of The Old West .', 'HUM'],
#  ['date When was Ozzy Osbourne born ?', 'NUM'],
#  ['reason Why do heavier objects travel downhill faster ?', 'DESC'],
#  ['ind Who was The Pride of the Yankees ?', 'HUM'],
#  ['ind Who killed Gandhi ?', 'HUM'],
#  ['event What is considered the costliest disaster the insurance industry has ever faced ?',
#   'ENTY'],
#  ['state What sprawling U.S. state boasts the most airports ?', 'LOC'],
#  ['desc What did the only repealed amendment to the U.S. Constitution deal with ?',
#   'DESC'],
#  ['count How many Jews were executed in concentration camps during WWII ?',
#   'NUM'],
#  ["def What is `` Nine Inch Nails '' ?", 'DESC'],
#  ['def What is an annotated bibliography ?', 'DESC'],
#  ['date What is the date of Boxing Day ?', 'NUM'],
#  ['other What articles of clothing are tokens in Monopoly ?', 'ENTY'],
#  ['ind Name 11 famous martyrs .', 'HUM'],
#  ["desc What 's the Olympic motto ?", 'DESC'],
#  ["desc What is the origin of the name ` Scarlett ' ?", 'DESC'],
#  ["letter What 's the second-most-used vowel in English ?", 'ENTY'],
#  ['ind Who was the inventor of silly putty ?', 'HUM'],
#  ['other What is the highest waterfall in the United States ?', 'LOC'],
#  ['other Name a golf course in Myrtle Beach .', 'ENTY'],
#  ['state Which two states enclose Chesapeake Bay ?', 'LOC'],
#  ['exp What does the abbreviation AIDS stand for ?', 'ABBR'],
#  ['other What does a spermologer collect ?', 'ENTY'],
#  ['count How many points make up a perfect fivepin bowling score ?', 'NUM'],
#  ["gr Which company that manufactures video-game hardware sells the `` super system '' ?",
#   'HUM'],
#  ['count How many Community Chest cards are there in Monopoly ?', 'NUM'],
#  ['desc What do Mormons believe ?', 'DESC'],
#  ['date When did the neanderthal man live ?', 'NUM'],
#  ['religion In what religion was Isis the nature goddess ?', 'ENTY'],
#  ["other Where do the adventures of `` The Swiss Family Robinson '' take place ?",
#   'LOC'],
#  ['animal What relative of the racoon is sometimes known as the cat-bear ?',
#   'ENTY'],
#  ['manner How can I register my website in Yahoo for free ?', 'DESC'],
#  ['other What was cash-conscious Colonel Edwin L. Drake the first to drill ?',
#   'ENTY'],
#  ['count How many people in the world speak French ?', 'NUM'],
#  ['count How many inches over six feet is the Venus de Milo ?', 'NUM'],
#  ['manner How do they find or choose witnesses to an execution ?', 'DESC'],
#  ['ind What 1920s cowboy star rode Tony the Wonder Horse ?', 'HUM'],
#  ['food What cocktail inspired John Doxat to write the book Stirred-Not Shaken ?',
#   'ENTY'],
#  ['gr What ISPs exist in the Caribbean ?', 'HUM'],
#  ['manner How do you ask a total stranger out on a date ?', 'DESC'],
#  ['other What weapon is the mythological character Apollo most proficient with ?',
#   'ENTY'],
#  ['country What country do the Galapagos Islands belong to ?', 'LOC'],
#  ['def What is ethology ?', 'DESC'],
#  ['ind Who was the prophet of the Muslim people ?', 'HUM'],
#  ["desc Where did the term `` 86ed '' come from ?", 'DESC'],
#  ["ind Who is Snoopy 's arch-enemy ?", 'HUM'],
#  ['def What is the nature of learning ?', 'DESC'],
#  ["color What 's the only color Johnny Cash wears on stage ?", 'ENTY'],
#  ["termeq What 's the term for a young fox ?", 'ENTY'],
#  ['state What U.S. state lived under six flags ?', 'LOC'],
#  ['def What is the Kashmir issue ?', 'DESC'],
#  ['other Where is the Loop ?', 'LOC'],
#  ["def What does `` extended definition '' mean and how would one write a paper on it ?",
#   'DESC'],
#  ["country What country 's capital is Tirana ?", 'LOC'],
#  ['def What is titanium ?', 'DESC'],
#  ['ind Who do Herb and Tootsie live next door to ?', 'HUM'],
#  ['city Which city has the oldest relationship as a sisterðcity with Los Angeles ?',
#   'LOC'],
#  ['def What is a caldera ?', 'DESC'],
#  ['reason Why do people get calluses ?', 'DESC'],
#  ['other What are the names of the tourist attractions in Reims ?', 'LOC'],
#  ['reason What are Cushman and Wakefield known for ?', 'DESC'],
#  ['other What body of water does the Danube River flow into ?', 'LOC'],
#  ['ind Who is the founder of Scientology ?', 'HUM'],
#  ['other What does the six-footed Musca domestica become when it enters a house ?',
#   'ENTY'],
#  ['desc What is the history of skateboarding ?', 'DESC'],
#  ['ind Who starred in Singing in the Rain and The Singing Nun ?', 'HUM'],
#  ['manner How do I make fuel bricks from recycled newspaper ?', 'DESC'],
#  ['ind What 19th-century painter died in the Marquesas Islands ?', 'HUM'],
#  ['body The corpus callosum is in what part of the body ?', 'ENTY'],
#  ['manner How do I log on to home page at Headquarters U.S. European Command ?',
#   'DESC'],
#  ['country What country did the Nazis occupy for 1 , CD NNS IN NNP NNP NNP .',
#   'LOC'],
#  ["other What is Nebraska 's most valuable resource ?", 'ENTY'],
#  ['count How many species of the Great White shark are there ?', 'NUM'],
#  ['desc What is the origin of head lice ?', 'DESC'],
#  ['state What is the nickname for the state of Mississippi ?', 'LOC'],
#  ['animal What was the first domesticated bird ?', 'ENTY'],
#  ['count How many villi are found in the small intestine ?', 'NUM'],
#  ['country What country did King Wenceslas rule ?', 'LOC'],
#  ['dismed What is a fear of shadows ?', 'ENTY'],
#  ['ind Who were the five Marx brothers ?', 'HUM'],
#  ['date In which year was New Zealand excluded from the ANZUS alliance ?',
#   'NUM'],
#  ['date When did CNN begin broadcasting ?', 'NUM'],
#  ['reason What causes the body to shiver in cold temperatures ?', 'DESC'],
#  ['def What are bear and bull markets ?', 'DESC'],
#  ['cremat What J.R.R. Tolkien book features Bilbo Baggins as the central character ?',
#   'ENTY'],
#  ["def What is `` dew point '' ?", 'DESC'],
#  ['def What is the meaning of Jesus ?', 'DESC'],
#  ["gr What company 's logo is a `` W '' in a circle ?", 'HUM'],
#  ['def What is the definition of a cascade ?', 'DESC'],
#  ['date When did Rococo painting and architecture flourish ?', 'NUM'],
#  ["country What country 's national passenger rail system is called Via ?",
#   'LOC'],
#  ['ind Who invented Make-up ?', 'HUM'],
#  ["desc What is the origin of the word `` attic '' ?", 'DESC'],
#  ["desc What did Delilah do to Samson 's hair ?", 'DESC'],
#  ['animal What kind of animals were in the Paleozoic era ?', 'ENTY'],
#  ['ind Which of the following was Rhodes Scholar ?', 'HUM'],
#  ['ind Who comprised the now-defunct comic book team known as the Champions ?',
#   'HUM'],
#  ['manner How do you make a paintball ?', 'DESC'],
#  ['state What U.S. state is Fort Knox in ?', 'LOC'],
#  ['animal What is a female rabbit called ?', 'ENTY'],
#  ['mount Where is the highest point in Japan ?', 'LOC'],
#  ['desc Where do chihuahuas come from ?', 'DESC'],
#  ["other Where does Barney Rubble go to work after he drops Fred off in the `` Flintstones '' cartoon series ?",
#   'LOC'],
#  ["other What are the world 's four oceans ?", 'LOC'],
#  ["cremat What 's the only work by Michelangelo that bears his signature ?",
#   'ENTY'],
#  ['animal What is the largest snake in the world ?', 'ENTY'],
#  ['cremat In what medium is Stuart Hamblen considered to be the first singing cowboy ?',
#   'ENTY'],
#  ['other Where on the Internet can I find a song lyrics database similar to the International Lyrics Server ?',
#   'LOC'],
#  ['money How much money does a back injury lawsuit get ?', 'NUM'],
#  ["termeq What 's the common name for acetylsalicylic acid ?", 'ENTY'],
#  ["def What does the Georgetown `` Hoya '' mean ?", 'DESC'],
#  ["other Where can I find a list of `` classic '' books 5th and 6th graders should read ?",
#   'LOC'],
#  ['product Which two products use a tiger as their symbol ?', 'ENTY'],
#  ['manner How is the election of a new Pope announced to the world ?', 'DESC'],
#  ['period How long does it take for your blood to make one complete trip through the body ?',
#   'NUM'],
#  ['manner How do chickens have baby chicks ?', 'DESC'],
#  ['desc What is the historical relationship of Catholic Church and bingo ?',
#   'DESC'],
#  ['manner How was the element calcium named ?', 'DESC'],
#  ['ind What crooner joined The Andrews Sisters for Pistol Packin Mama ?',
#   'HUM'],
#  ["gr What piano company claims its product is the `` Instrument of the immortals '' ?",
#   'HUM'],
#  ['date When did the Bounty mutiny take place ?', 'NUM'],
#  ['cremat What novel inspired the movie BladeRunner ?', 'ENTY'],
#  ['def What is a transistor ?', 'DESC'],
#  ['cremat What is a film starring Jude Law ?', 'ENTY'],
#  ['animal What Hollywood dog died in the arms of Jean Harlow in 1932 ?',
#   'ENTY'],
#  ["substance What are the most common elements in the Earth 's crust ?",
#   'ENTY'],
#  ['money How much would it cost to purchase a 2-foot-square party tent , with sides , ?',
#   'NUM'],
#  ['ind What actress has received the most Oscar nominations ?', 'HUM'],
#  ['def What are equity securities ?', 'DESC'],
#  ['def What is gymnophobia ?', 'DESC'],
#  ['count How many years do fossils take to form ?', 'NUM'],
#  ['other Where is the Orinoco ?', 'LOC'],
#  ["animal What was the name of the `` Little Rascals '' dog ?", 'ENTY'],
#  ["city What city boasts Penn 's Landing , on the banks of the Delaware river ?",
#   'LOC'],
#  ["cremat What Broadway musical was inspired by Cervantes 's Don Quixote ?",
#   'ENTY'],
#  ['desc What is the origin of the word , JJ .', 'DESC'],
#  ['count How many hostages were killed in the Entebbe raid ?', 'NUM'],
#  ['manner How you can raise your IQ ?', 'DESC'],
#  ["exp What does INRI stand for when used on Jesus ' cross ?", 'ABBR'],
#  ['gr Who produces Spumante ?', 'HUM'],
#  ['ind Who earns their money the hard way ?', 'HUM'],
#  ["ind Who founded the People 's Temple Commune ?", 'HUM'],
#  ['ind What athlete makes the most money from sports merchandise sales ?',
#   'HUM'],
#  ['count How many bends are there in a standard paper clip ?', 'NUM'],
#  ['ind Who discovered electricity ?', 'HUM'],
#  ['body What part of your body contains the corpus callosum ?', 'ENTY'],
#  ['ind Who was the first American in space ?', 'HUM'],
#  ["country What two South American countries do n't border Brazil ?", 'LOC'],
#  ['cremat What album put The Beatles on the cover of Time in 1967 ?', 'ENTY'],
#  ["cremat What poem contains the line , `` grow old with me the best is yet to be '' .",
#   'ENTY'],
#  ['def What is a dental root canal ?', 'DESC'],
#  ['event What war did the Wanna-Go-Home Riots occur after ?', 'ENTY'],
#  ['date What is the busiest air travel season ?', 'NUM'],
#  ["body What 's the colored part of the eye called ?", 'ENTY'],
#  ['def What are hook worms ?', 'DESC'],
#  ['other Where is the Rose Bowl played ?', 'LOC'],
#  ['gr Which Japanese car maker had its biggest percentage of sale in the domestic market ?',
#   'HUM'],
#  ['ind Who is the mayor of Marbella ?', 'HUM'],
#  ['other What sun-blasted , 14-mile wide valley is just north of the Mojave desert ?',
#   'LOC'],
#  ['date In what year did Thatcher become prime minister ?', 'NUM'],
#  ['count How many months does it take the moon to revolve around the Earth ?',
#   'NUM'],
#  ['other Where are the 49 steps ?', 'LOC'],
#  ['date In what year was De Gaulle elected president of France ?', 'NUM'],
#  ["ind Who sings the themes for `` Dawson 's Creek '' and `` Felicity '' ?",
#   'HUM'],
#  ["ind Who directed `` Jaws '' ?", 'HUM'],
#  ['cremat On what T.V. show could Tom Terrific be found ?', 'ENTY'],
#  ['gr What Indian tribe is F Troop perpetually doing battle with ?', 'HUM'],
#  ['desc Where did Indian Pudding come from ?', 'DESC'],
#  ["reason Why do some clothing labels say `` Use a nonchlorine bleach '' ?",
#   'DESC'],
#  ['count How many colonies were involved in the American Revolution ?', 'NUM'],
#  ['city What is the name of the city that Maurizio Pellegrin lives in ?',
#   'LOC'],
#  ['other Where can I find pictorial directions on how to build a very simple treehouse ?',
#   'LOC'],
#  ["sport What game 's board shows the territories of Irkutsk , Yakutsk and Kamchatka ?",
#   'ENTY'],
#  ['ind What is the name of the managing director of Apricot Computer ?',
#   'HUM'],
#  ['title What is the occupation of Nicholas Cage ?', 'HUM'],
#  ['reason Why do horseshoes bring luck ?', 'DESC'],
#  ['def What is the 401 , K , plan ?', 'DESC'],
#  ['reason What causes pneumonia ?', 'DESC'],
#  ['date What are the three winter months in the southern hemisphere ?', 'NUM'],
#  ['def What does gringo mean ?', 'DESC'],
#  ["country What country contains Africa 's northernmost point ?", 'LOC'],
#  ["dismed What therapy attempts to elicit the `` primal scream '' ?", 'ENTY'],
#  ['other Where is the Kalahari desert ?', 'LOC'],
#  ["gr Which Ventura County police department seized the largest cocaine shipment in it 's history ?",
#   'HUM'],
#  ['city What city is sometimes called Gotham ?', 'LOC'],
#  ['body What dangles over the tongue from the palate ?', 'ENTY'],
#  ['ind Who created Dennis the Menace ?', 'HUM'],
#  ['ind What dummy received an honorary degree from Northwestern University ?',
#   'HUM'],
#  ['date When was the first Wall Street Journal published ?', 'NUM'],
#  ['country What countries have the largest areas of forest ?', 'LOC'],
#  ['manner How do I start a web based business ?', 'DESC'],
#  ["ind Name Alvin 's brothers", 'HUM'],
#  ["def What is Eagle 's syndrome styloid process ?", 'DESC'],
#  ['manner How did Jayne Mansfield die ?', 'DESC'],
#  ['date When did the royal wedding of Prince Andrew and Fergie take place ?',
#   'NUM'],
#  ['ind What actor said in A Day at the Races', 'HUM'],
#  ["ind What explorer was nicknamed Iberia 's Pilot ?", 'HUM'],
#  ['date CNN began broadcasting in what year ?', 'NUM'],
#  ['termeq What is a ball that hits the foul pole called ?', 'ENTY'],
#  ['reason What makes hamburgers taste like steakburgers ?', 'DESC'],
#  ['gr Which company created the Internet browser Mosaic ?', 'HUM'],
#  ['event What are the rites accompanying the circumcision of a newly born-child in Judaism called ?',
#   'ENTY'],
#  ["other What was the education system in the 1960 's ?", 'ENTY'],
#  ["city What South American city has the world 's highest commercial landing field ?",
#   'LOC'],
#  ['manner How can I find out which cities have cable-modem access ?', 'DESC'],
#  ['reason What is Betsy Ross famous for ?', 'DESC'],
#  ['count How many species of sharks are there ?', 'NUM'],
#  ["def What is `` snoogans '' ?", 'DESC'],
#  ['count How many people are there in the world ?', 'NUM'],
#  ['plant What shrubs can be planted that will be safe from deer ?', 'ENTY'],
#  ["gr What organization 's offices were broken into at Watergate in 1972 ?",
#   'HUM'],
#  ['desc What is the design of the ship Titanic ?', 'DESC'],
#  ['exp What does S.O.S. stand for ?', 'ABBR'],
#  ['techmeth Name a technique widely used to detect birth defects ?', 'ENTY'],
#  ['desc What is the daily requirement of folic acid for an expectant mother ?',
#   'DESC'],
#  ["def What is the `` 7-minute cigarette '' ?", 'DESC'],
#  ['other What four forms does gold occur in ?', 'ENTY'],
#  ['volsize What is the acreage of the Chappellet vineyard ?', 'NUM'],
#  ["manner How do you correctly say the word ` qigong ' ?", 'DESC'],
#  ['date When did beethoven die ?', 'NUM'],
#  ['money How much does a new railroad coal car cost ?', 'NUM'],
#  ['country What two European countries entered the War of American Independence against the British ?',
#   'LOC'],
#  ['def What is the filmmakers collabrative ?', 'DESC'],
#  ["ind What Russian composer 's Prelude in C Sharp Minor brought him fame and fortune ?",
#   'HUM'],
#  ["reason What caused Harry Houdini 's death ?", 'DESC'],
#  ['ind Who was the mother of the man who would not be king , the duke of Windsor ?',
#   'HUM'],
#  ['count How many revolutions does a standard LP make in three minutes ?',
#   'NUM'],
#  ['mount What is the name of the tallest mountain in the world ?', 'LOC'],
#  ['other Where can I find a review of Nightmare on Elm Street in a film journal ?',
#   'LOC'],
#  ["techmeth What 's the slowest Olympic swimming stroke ?", 'ENTY'],
#  ['ind What was the name of the first Russian astronaut to do a spacewalk ?',
#   'HUM'],
#  ['dismed What disease is transmitted by the Anopheles mosquito ?', 'ENTY'],
#  ["food What rum is so `` mixable '' it is a one-brand bar ?", 'ENTY'],
#  ['count How many South American countries have the letter Z in their names ?',
#   'NUM'],
#  ['def What is the contents of proposition 98 ?', 'DESC'],
#  ['other Where was George Washington born ?', 'LOC'],
#  ['count How many people on the ground were killed from the bombing of Pan Am Flight 103 over Lockerbie , Scotland , December 21 , CD .',
#   'NUM'],
#  ["ind Who wrote NN DT NNP NNP '' ?", 'HUM'],
#  ['def What is paracetamol ?', 'DESC'],
#  ["desc What are the powers and weaknesses of Green Lantern 's ring ?",
#   'DESC'],
#  ["animal Which mosquito 's bite draws blood , DT NN CC DT NN .", 'ENTY'],
#  ['date When was the first steel mill in the United States built ?', 'NUM'],
#  ['ind What diminutive American female gymnast stole the show at the 1984 Olympics ?',
#   'HUM'],
#  ['desc What is the origin of the name Katie ?', 'DESC'],
#  ['gr What schools in the Washington , DC NN NN VBP NN NN NN NN .', 'HUM'],
#  ['date When did the Berlin Wall go up ?', 'NUM'],
#  ['desc Who is Terrence Malick ?', 'HUM'],
#  ['instru What instrument is Ray Charles best known for playing ?', 'ENTY'],
#  ["def What 's the meaning of the Latin battle cry", 'DESC'],
#  ['other What is the mascot for Notre Dame University ?', 'ENTY'],
#  ['other What Las Vegas hotel burned in November , 1980 , with the loss of 84 lives ?',
#   'LOC'],
#  ['date When did Mount St. Helen last have a significant eruption ?', 'NUM'],
#  ['exp CNN is the abbreviation for what ?', 'ABBR'],
#  ['date When did World War I start ?', 'NUM'],
#  ['count How many feet are there in a fathom ?', 'NUM'],
#  ['def What is a Canada two-penny black ?', 'DESC'],
#  ['city What European city do Nicois live in ?', 'LOC'],
#  ['manner How can I find out what year a Beanie Baby was introduced ?',
#   'DESC'],
#  ['def What is the classic definition of tragic hero ?', 'DESC'],
#  ["other To what does Microsoft 's Windows 3 owe its success ?", 'ENTY'],
#  ['ind Who was President of Afghanistan in 1994 ?', 'HUM'],
#  ['techmeth What are other ways of getting stretch marks besides pregnancy , weight loss , and weight lifting ?',
#   'ENTY'],
#  ['food What did brontosauruses eat ?', 'ENTY'],
#  ['color What color bottles do good Rhine wines come in ?', 'ENTY'],
#  ["ind Who was the lead actress in the movie ` Sleepless in Seattle ' ?",
#   'HUM'],
#  ['ind Who was the 16th President of the United States ?', 'HUM'],
#  ['ind Who are the two sons of Ozzie and Harriet Nelson ?', 'HUM'],
#  ['def What is molybdenum ?', 'DESC'],
#  ['date When is Boxing Day ?', 'NUM'],
#  ['other What is the lowest level of the American judiciary ?', 'ENTY'],
#  ['date When was the battle of the Somme fought ?', 'NUM'],
#  ['count How many people did Randy Craft kill ?', 'NUM'],
#  ["animal What 's the official animal of Canada ?", 'ENTY'],
#  ["date When did Spielberg direct `` Jaws '' ?", 'NUM'],
#  ['volsize What is the size of the largest akita ?', 'NUM'],
#  ['animal What animal has the biggest eyes ?', 'ENTY'],
#  ["city What is California 's capital ?", 'LOC'],
#  ["ind Who was the author of the book about computer hackers called `` The Cuckoo 's Egg",
#   'HUM'],
#  ['ind Who was the founding member of the Pink Floyd band ?', 'HUM'],
#  ['country What European country is home to the beer-producing city of Budweis ?',
#   'LOC'],
#  ['manner How do I find the balance of my social security account ?', 'DESC'],
#  ["desc What is the history of Valentine 's Day cards ?", 'DESC'],
#  ['other Where was Christopher Columbus born ?', 'LOC'],
#  ['termeq What do Italians call Florence ?', 'ENTY'],
#  ['manner How do you get to the top of the Eiffel Tower ?', 'DESC'],
#  ["exp What does ` PSI ' stand for ?", 'ABBR'],
#  ['other What sea did the Romans call mare nostrum ?', 'LOC'],
#  ["termeq What 's the term for a bet before cards are dealt ?", 'ENTY'],
#  ['animal Which came first , according to Genesis 1', 'ENTY'],
#  ['city What city did the Flintstones live in ?', 'LOC'],
#  ['termeq What is Latin for incompetent ?', 'ENTY'],
#  ['dismed What chemicals are used in lethal injection ?', 'ENTY'],
#  ["gr What toy company is the world 's No.1 maker of female apparel ?", 'HUM'],
#  ["sport What board game does a `` wood-pusher '' play poorly ?", 'ENTY'],
#  ['ind Which Doonesbury character was likely to turn into a werewolf ?',
#   'HUM'],
#  ['abb What is the abbreviation for micro ?', 'ABBR'],
#  ['other What are the 7 articles of the constitution ?', 'ENTY'],
#  ['gr Who has won the most Super Bowls ?', 'HUM'],
#  ['exp What does NASDAQ stand for ?', 'ABBR'],
#  ['exp What is BPH ?', 'ABBR'],
#  ['other What is the fastest commercial automobile that can be bought in the US ?',
#   'ENTY'],
#  ['other What stadium do the Miami Dolphins play their home games in ?',
#   'LOC'],
#  ["ind Who has the only speaking role in `` Silent Movie '' ?", 'HUM'],
#  ['reason Why is poop sometimes different colors ?', 'DESC'],
#  ["other What was Einstein 's IQ ?", 'NUM'],
#  ['date What day was Pearl Harbor attacked in 1942 ?', 'NUM'],
#  ["ind What girl 's name is `` Teddy '' an affectionate form of ?", 'HUM'],
#  ['state What state is John F. Kennedy buried in ?', 'LOC'],
#  ['techmeth What is the best way to remove wallpaper ?', 'ENTY'],
#  ['state What U.S. state has an element named for it ?', 'LOC'],
#  ['gr What company tabulates the ballots in voting for the Academy Awards ?',
#   'HUM'],
#  ['manner How did the tradition of best man start ?', 'DESC'],
#  ['count How many years ago did the ship Titanic sink ?', 'NUM'],
#  ['other What is the deepest area of the Arctic Ocean ?', 'LOC'],
#  ["color What are Halloween 's colors ?", 'ENTY'],
#  ['manner How is silk screening done ?', 'DESC'],
#  ['other What is the latitude and longitude of El Paso , Texas ?', 'NUM'],
#  ['ind Who made a boat out of gopher wood ?', 'HUM'],
#  ["other Where can I find a `` Fifth Element '' screensaver ?", 'LOC'],
#  ['ind Which Bloom County resident wreaks havoc with a computer ?', 'HUM'],
#  ['manner How do you match a name to a social security number ?', 'DESC'],
#  ['manner How does a rainbow form ?', 'DESC'],
#  ['other What is the normal resting heart rate of a healthy adult ?', 'NUM'],
#  ['other What is the population of Ohio ?', 'NUM'],
#  ['count How many calories are there in a Big Mac ?', 'NUM'],
#  ['def Hazmat stands for what ?', 'DESC'],
#  ["animal What creature scares people in the film `` Jaws '' ?", 'ENTY'],
#  ['ind What part did John Peter Zenger play in the deveopment of the newspaper in America ?',
#   'HUM'],
#  ['ind Who followed Caesar ?', 'HUM'],
#  ['substance What are the four elements ?', 'ENTY'],
#  ['ind Who was the first woman golfer to earn a million ?', 'HUM'],
#  ["other What 's the tallest piece on a chessboard ?", 'ENTY'],
#  ["other What is Answers.com 's address ?", 'LOC'],
#  ['other Where can I buy movies on videotape online ?', 'LOC'],
#  ['ind Who does the advertizing for Frito-Lay ?', 'HUM'],
#  ['gr Who is the leading competitor of Trans Union Company ?', 'HUM'],
#  ['product What product did Robert Conrad dare people to knock off his shoulder ?',
#   'ENTY'],
#  ['ind Who invented the radio ?', 'HUM'],
#  ["count What 's the American dollar equivalent for 8 pounds in the U.K. ?",
#   'NUM'],
#  ['techmeth What are the different approaches of systems analysis ?', 'ENTY'],
#  ['manner How do doctors diagnose bone cancer ?', 'DESC'],
#  ['ind Who is the man behind the pig-the man who pulls the strings and speaks for Miss Piggy ?',
#   'HUM'],
#  ['speed What is the speed of the Mississippi River ?', 'NUM'],
#  ['other What are the developmental stages of a swimmer ?', 'ENTY'],
#  ['ind What actor first portrayed James Bond ?', 'HUM'],
#  ['other What ocean is the largest in the world ?', 'LOC'],
#  ['ind Who was the first American poet to win the Nobel Prize for literature , in 1948 ?',
#   'HUM'],
#  ['date What year did Jack Nicklaus join the Professional Golfers Association tour ?',
#   'NUM'],
#  ['count How many sonnets did Shakespeare write ?', 'NUM'],
#  ['reason What causes the redness in your cheeks when you blush ?', 'DESC'],
#  ['ind Who won the Nobel Peace Prize in 1991 ?', 'HUM'],
#  ['gr Who are the Challengers of the Unknown ?', 'HUM'],
#  ['def Define the Pheonix Club ?', 'DESC'],
#  ['city Which city did Christian Crusaders fight to recapture from the Muslims ?',
#   'LOC'],
#  ["def What does it mean `` Rupee Depreciates '' ?", 'DESC'],
#  ["other What gaming devices were dubbed `` Mississippi marbles '' and `` Memphis dominoes '' ?",
#   'ENTY'],
#  ['ind Who was the first coach of the Cleveland Browns ?', 'HUM'],
#  ['manner How successful is arometherapy ?', 'DESC'],
#  ['event What Jewish holiday saw the start of the 1973 Mideast War ?', 'ENTY'],
#  ['manner How does a copier work ?', 'DESC'],
#  ['speed What is the speed of the Mississippi River ?', 'NUM'],
#  ['ind Who said of Super Bowl III in 1969', 'HUM'],
#  ["animal What is Dudley Do-Right 's horse 's name ?", 'ENTY'],
#  ['ind Who declared', 'HUM'],
#  ['other Where does chocolate come from ?', 'LOC'],
#  ['cremat What TV game show once saw a contestant admit to picking his toes in the shower ?',
#   'ENTY'],
#  ['ind What Soviet leader owned a Rolls-Royce ?', 'HUM'],
#  ['other Where can I find a case on Individuals with Disabilities Education Act of 1991 ?',
#   'LOC'],
#  ['event What war did Florence Nightingale tend the troops in ?', 'ENTY'],
#  ["ind Who wrote the song , `` Stardust '' ?", 'HUM'],
#  ["count How many Beatles ' records went #1 ?", 'NUM'],
#  ['ind Who is the only prime minister of Canada to serve 22 years but not necessarily consecutively ?',
#   'HUM'],
#  ["abb What is the abbreviation of the company name ` General Motors ' ?",
#   'ABBR'],
#  ['mount What mountains lie between the Arkansas and Missouri rivers ?',
#   'LOC'],
#  ['ind Who received the Will Rogers Award in 1989 ?', 'HUM'],
#  ['reason What is the function of RAM ?', 'DESC'],
#  ["other What 's the closest G2 Spectrum Yellow Dwarf to Earth ?", 'LOC'],
#  ['count How many equal angles are there in an isosceles triangle ?', 'NUM'],
#  ['dismed What is the fear of cockroaches called ?', 'ENTY'],
#  ["cremat What CBS soap opera was interrupted by the bulletin of John F. Kennedy 's assassination ?",
#   'ENTY'],
#  ['desc What is the use of a 24-hour clock instead of a 12-hour clock ?',
#   'DESC'],
#  ['ind What was the name of the lawyer who represented Randy Craft ?', 'HUM'],
#  ['ind What United States President had dreamed that he was assassinated ?',
#   'HUM'],
#  ['cremat What film did Lee Marvin win the 1965 best actor Oscar for ?',
#   'ENTY'],
#  ['other Where is Basque country located ?', 'LOC'],
#  ["product What product does `` Mrs. Olsen '' promote ?", 'ENTY'],
#  ['date What time of day did Emperor Hirohito die ?', 'NUM'],
#  ['def What is dry ice ?', 'DESC'],
#  ["other What 's the most powerful card in Euchre ?", 'ENTY'],
#  ["def What does `` intractable plantar keratoma '' mean ?", 'DESC'],
#  ['count How many years did it take James Joyce to write Ulysses ?', 'NUM'],
#  ['food What crop failure caused the Irish Famine ?', 'ENTY'],
#  ['city What South Korean city is served by Kimpo International Airport ?',
#   'LOC'],
#  ["count How many types of dogs ' tails are there - three", 'NUM'],
#  ['cremat What is the longest-running television series ?', 'ENTY'],
#  ['animal What predators exist on Antarctica ?', 'ENTY'],
#  ['desc What is the difference between a generator and an alternator ?',
#   'DESC'],
#  ['manner How is energy created ?', 'DESC'],
#  ["food What beer advertised that it had `` three rings '' ?", 'ENTY'],
#  ['other What is the quantity of American soldiers still unaccounted for from the Vietnam war ?',
#   'NUM'],
#  ['techmeth What golfing accessory was patented by George Grant on December 12',
#   'ENTY'],
#  ['other What are the different types of plastic ?', 'ENTY'],
#  ["manner How is it correct to say ` qigong ' ?", 'DESC'],
#  ['mount What was the highest mountain on earth before Mount Everest was discovered ?',
#   'LOC'],
#  ['other Where was the Ligurian Republic , 1797-185 , ?', 'LOC'],
#  ["country What country 's people are the top television watchers ?", 'LOC'],
#  ["date When was the women 's suffrage amendment ratified ?", 'NUM'],
#  ['gr What Polynesian people inhabit New Zealand ?', 'HUM'],
#  ['cremat What movie tour of the Roman empire features the admonition',
#   'ENTY'],
#  ['city What Nevada center has been dubbed The Biggest Little City in the World ?',
#   'LOC'],
#  ['ind What President lived at 219 North Delaware Street , Independence , Missouri ?',
#   'HUM'],
#  ['reason Give a reason for American Indians oftentimes dropping out of school .',
#   'DESC'],
#  ['other Where must a soccer goalie stand to be permitted to handle the ball ?',
#   'LOC'],
#  ['desc What is the difference between classical conditioning and operant conditioning ?',
#   'DESC'],
#  ['state In what U.S. state was the first woman governor elected ?', 'LOC'],
#  ['desc What are some interesting facts and information about dogsledding ?',
#   'DESC'],
#  ['date What year did Hitler die ?', 'NUM'],
#  ['ind What famous model was married to Billy Joel ?', 'HUM'],
#  ['animal What kind of animal is Babar ?', 'ENTY'],
#  ['reason What is Jane Goodall known for ?', 'DESC'],
#  ['other What killed Bob Marley ?', 'ENTY'],
#  ["money How much money are Dumbo 's ears insured for ?", 'NUM'],
#  ["ind Who danced into stardom with Fred Astaire in 1941 's You 'll Never Get Rich ?",
#   'HUM'],
#  ['desc Who is Stein Eriksen ?', 'HUM'],
#  ['def What does the name Billie mean ?', 'DESC'],
#  ['ind Who is the fastest swimmer in the world ?', 'HUM'],
#  ['mount What is the highest peak in Africa ?', 'LOC'],
#  ['other Where is Procter & Gamble headquartered in the U.S. ?', 'LOC'],
#  ['other What desert has been called The Garden of Allah ?', 'LOC'],
#  ['other What do bicornate animals have two of ?', 'ENTY'],
#  ["reason What function does a community 's water tower serve ?", 'DESC'],
#  ['dismed What is a fear of weakness ?', 'ENTY'],
#  ['count How many miles is it to Ohio from North Carolina ?', 'NUM'],
#  ['count How much snow equals an inch of rain ?', 'NUM'],
#  ['exp What does G.M.T. stand for ?', 'ABBR'],
#  ['def What does Inuit and Eskimo mean ?', 'DESC'],
#  ['cremat What song served as the closing theme of The Johnny Cash Show ?',
#   'ENTY'],
#  ['sport What field sport did dentist William Beers promote and write a standard book of rules for ?',
#   'ENTY'],
#  ['manner How do I tie dye clothes ?', 'DESC'],
#  ['date When does the average teenager first have intercourse ?', 'NUM'],
#  ["reason Why doesn 't www.answers.com have any answers to my questions ?",
#   'DESC'],
#  ["ind What actor 's autobiography is titled All My Yesterdays ?", 'HUM'],
#  ['ind What Russian master spy lived in the U.S. under the name Emil Goldfus ?',
#   'HUM'],
#  ["other Where 's the 19th hole on a golf course ?", 'LOC'],
#  ["reason What 's nature 's purpose for tornadoes ?", 'DESC'],
#  ["ind Who played the original Charlie 's Angels ?", 'HUM'],
#  ["other Where can I find a person 's address from a telephone number ?",
#   'LOC'],
#  ['word What English word comes from the Old French covrefeu , meaning cover fire ?',
#   'ENTY'],
#  ["instru What musical instrument did Prewitt play in James Jones 's From Here to Eternity ?",
#   'ENTY'],
#  ['other Where did Sarge Steel get his metal hand ?', 'LOC'],
#  ['reason What makes popcorn pop ?', 'DESC'],
#  ['ind Who wrote The Night of the Iguana ?', 'HUM'],
#  ['body Where does your hair grow the fastest ?', 'ENTY'],
#  ['country What country did King Gustav V reign over from 197 to 195 ?',
#   'LOC'],
#  ['ind Who painted Mother and Child ?', 'HUM'],
#  ['speed What is the speed of the Mississippi River ?', 'NUM'],
#  ['other In what area of the world was the Six Day War fought ?', 'LOC'],
#  ['other What is the brightest star visible from Earth ?', 'LOC'],
#  ["cremat What film marked Robert Redford 's directorial debut ?", 'ENTY'],
#  ["ind What was Mao 's second name ?", 'HUM'],
#  ['cremat What film or films has Jude Law appeared in ?', 'ENTY'],
#  ['other Where do hyenas live ?', 'LOC'],
#  ["desc Who is the `` Queen Mother '' ?", 'HUM'],
#  ["lang What 's the most commonly-spoken language in Belgium ?", 'ENTY'],
#  ['ind Who has more DNA - a man or a woman ?', 'HUM'],
#  ['def What are Maid-Rites ?', 'DESC'],
#  ["cremat What children 's tale contains the line", 'ENTY'],
#  ['gr What level of government or governmental agency is responsible for dealing with racism ?',
#   'HUM'],
#  ['count How many referees work a soccer game ?', 'NUM'],
#  ['food What cocktail do you concoct with whisky and sweet vermouth ?',
#   'ENTY'],
#  ["termeq How do you say `` fresh '' in Spanish ?", 'ENTY'],
#  ['desc What do bee hives do in cranberry bogs ?', 'DESC'],
#  ['reason What caused the Lynmouth floods ?', 'DESC'],
#  ['date When is the Tulip Festival in Michigan ?', 'NUM'],
#  ['ind Who came up with the name , El Nino ?', 'HUM'],
#  ['cremat What movie did Madilyn Kahn star in with Gene Wilder ?', 'ENTY'],
#  ['other What type of bridge is the Golden Gate Bridge ?', 'ENTY'],
#  ["ind What dictator has the nickname `` El Maximo '' ?", 'HUM'],
#  ["gr What stereo manufacturer is `` Slightly ahead of its time '' ?", 'HUM'],
#  ['city What U.S. city is The Queen of the Pacific ?', 'LOC'],
#  ['ind What TV sitcom character had the maiden name Ethel Potter ?', 'HUM'],
#  ['food What was the first Lifesaver flavor ?', 'ENTY'],
#  ['ind Who kept the most famous diary in the English language ?', 'HUM'],
#  ['other Where can I find out the top 1 singles ?', 'LOC'],
#  ['count How many degrees cooler is the inside of a cucumber than the air outside ?',
#   'NUM'],
#  ['ind What Spanish artist painted Crucifixion ?', 'HUM'],
#  ['cremat What is the Jewish bible called ?', 'ENTY'],
#  ['reason Why is the grass green ?', 'DESC'],
#  ['def What is a firewall ?', 'DESC'],
#  ['ind What spy novelist served as Moscow correspondent for Reuter and The Times of London ?',
#   'HUM'],
#  ["gr Which oil company almost picked a word that meant `` stalled car '' in Japanese as its new international name ?",
#   'HUM'],
#  ["period How long does it take for Spider-Man 's web to evaporate ?", 'NUM'],
#  ["ind Who was Randy Steven Craft 's lawyer ?", 'HUM'],
#  ['other What was known as the Spice Island ?', 'LOC'],
#  ['ind Who was the first host of Person to Person ?', 'HUM'],
#  ['ind Name the Ranger who was always after Yogi Bear .', 'HUM'],
#  ['other What deck of cards includes the Wheel of Fortune , the Lovers , and Death ?',
#   'ENTY'],
#  ['other What does the Statue of Liberty wear on her feet ?', 'ENTY'],
#  ['ind Who is the superstar in rent-a-cars ?', 'HUM'],
#  ['city McCarren Airport is located in what city ?', 'LOC'],
#  ['other What household facility contains a float ball , ballcock , and overflow tube ?',
#   'ENTY'],
#  ["animal What was the name of Betty Boop 's dog ?", 'ENTY'],
#  ["perc What fraction of a beaver 's life is spent swimming ?", 'NUM'],
#  ['substance What was the Bridge of San Luis Rey made of ?', 'ENTY'],
#  ['desc What do economists do ?', 'DESC'],
#  ['country What country has the largest sheep population ?', 'LOC'],
#  ['desc What do I need to do to take my dog with me to live in Dominica , West Indies for a year ?',
#   'DESC'],
#  ["country What country is the world 's largest importer of cognac ?", 'LOC'],
#  ['count How many years is Johnnie Walker Black Label aged ?', 'NUM'],
#  ['exp What does SIDS stand for ?', 'ABBR'],
#  ["other What is Grenada 's main commodity export ?", 'ENTY'],
#  ['money How much would a black-and-white 1-cent stamp be worth , Thomas Jefferson on it , ?',
#   'NUM'],
#  ['reason What makes a clitoris sensitive ?', 'DESC'],
#  ['country What country has the most time zones , with 11 ?', 'LOC'],
#  ["other What `` magic '' does Mandrake employ ?", 'ENTY'],
#  ['ind Who is the president of Stanford University ?', 'HUM'],
#  ['ind Whose first presidential order was', 'HUM'],
#  ['other What was introduced commercially by Bayer A.G. of Leverkusen , in 1899 ?',
#   'ENTY'],
#  ['city What city is Logan Airport in ?', 'LOC'],
#  ['def What is a nanometer ?', 'DESC'],
#  ['count How many innings are there in a regulation softball game ?', 'NUM'],
#  ['date When did CNN go on the air ?', 'NUM'],
#  ['city What is the largest city on the Great Lakes ?', 'LOC'],
#  ['code What is the telephone number for the University of Kentucky ?', 'NUM'],
#  ['ind Who invented baseball ?', 'HUM'],
#  ['count How many wives did Brigham Young have ?', 'NUM'],
#  ['product What product on the market is good for hiding facial scars ?',
#   'ENTY'],
#  ['dist How long is the Coney Island boardwalk ?', 'NUM'],
#  ['city What city gained renown for its pea-soup fogs ?', 'LOC'],
#  ["def What does `` Janelle '' mean ?", 'DESC'],
#  ["manner How do I get another city 's newspaper ?", 'DESC'],
#  ['cremat Name a movie about the Sioux Indians starring Kevin Costner .',
#   'ENTY'],
#  ['ind Who was shot in the back during a Poker game in Deadwood , the Dakota territory ?',
#   'HUM'],
#  ['desc What are the distinct physical characterstics of the Arabian horse ?',
#   'DESC'],
#  ['dismed What is a fear of thunder ?', 'ENTY'],
#  ['animal What animal has killed the most people ?', 'ENTY'],
#  ['count How many colleges are in Wyoming ?', 'NUM'],
#  ["city What Russian seaport has a name meaning `` Lord of the East '' ?",
#   'LOC'],
#  ['other Where can stocks be traded on-line ?', 'LOC'],
#  ['date When was the Battle of Hastings ?', 'NUM'],
#  ['other What kind of file has the extension .dbf ?', 'ENTY'],
#  ['date When did Muhammad live ?', 'NUM'],
#  ['termeq What then-derogatory term was applied to the painters Monet , Sisley , Pissarro , Renoir and Degas ?',
#   'ENTY'],
#  ['def What is a wop ?', 'DESC'],
#  ['desc Where do rocks come from ?', 'DESC'],
#  ['manner How do I stop background noise in a car stereo ?', 'DESC'],
#  ['mount Where do people mountain climb in Nepal ?', 'LOC'],
#  ['gr What is the best college in the country ?', 'HUM'],
#  ['def What is viscosity ?', 'DESC'],
#  ['cremat What was the name of the sitcom that Alyssa Milano starred in with Tony Danza ?',
#   'ENTY'],
#  ['country What are the Nordic nations ?', 'LOC'],
#  ['other Where on the Internet can I get information about the Fifth Amendment on the American Bill of Rights ?',
#   'LOC'],
#  ['state What U.S. state borders Illinois to the north ?', 'LOC'],
#  ['cremat Name a film in which Jude Law acted .', 'ENTY'],
#  ['temp What is the temperature for baking Peachy Oat Muffins ?', 'NUM'],
#  ['dismed What is a fear of bees ?', 'ENTY'],
#  ['cremat What Vladimir Nabokov novel features Professor Humbert in love with a 12-year-old girl ?',
#   'ENTY'],
#  ['def What is a green bog ?', 'DESC'],
#  ['other Where did the myth of Santa Claus originate ?', 'LOC'],
#  ['other What does a chairbound basophobic fear ?', 'ENTY'],
#  ['city What city is served by Logan International Airport ?', 'LOC'],
#  ["ind What wrestling star became `` The Incredible Hulk '' ?", 'HUM'],
#  ['other What attracts tourists to Reims ?', 'LOC'],
#  ['sport What game do Steve McQueen and Edward G. Robinson play in The Cincinnati Kid ?',
#   'ENTY'],
#  ['other What fastener did Whitcomb Judson patent in 1893 ?', 'ENTY'],
#  ["def What 's an auberge in France ?", 'DESC'],
#  ['ind Who was the star of the 1965 Broadway hit Golden Boy ?', 'HUM'],
#  ['other Where is Procter & Gamble based in the U.S. ?', 'LOC'],
#  ['gr What army was founded by William Booth and his wife Catherine ?', 'HUM'],
#  ['substance What does ribavirin consist of ?', 'ENTY'],
#  ["food Name the soft drink that is `` number one in the sun . ''", 'ENTY'],
#  ['other What is the web address of the list of e-mail addresses of members of the House of Representatives ?',
#   'LOC'],
#  ['ind What was her real name ?', 'HUM'],
#  ['reason Why are the ears your center of balance ?', 'DESC'],
#  ['ind Who invented the toothbrush ?', 'HUM'],
#  ['cremat What was the name of that popular song the Creeps sang ?', 'ENTY'],
#  ['other Where is the Abominable Snowman said to wander ?', 'LOC'],
#  ['dismed What is a fear of being alone ?', 'ENTY'],
#  ["count How many dots make up the symbol for `` because '' ?", 'NUM'],
#  ['food What do you get by adding Lactobacillus bulgaricus to milk ?', 'ENTY'],
#  ['exp When reading classified ads , what does EENTY', 'ABBR'],
#  ['count How many hearts does an octopus have ?', 'NUM'],
#  ['plant What plant has the largest seed ?', 'ENTY'],
#  ['country What was the only country you were allowed to drive into Israel from in 1979 ?',
#   'LOC'],
#  ["other What 's approaching when a cyclist shouts", 'ENTY'],
#  ["ind What baseball star turned down a $1 , 000-a-year contract because he felt he had n't earned it ?",
#   'HUM'],
#  ['sport What kind of sport is often associated with hooligans ?', 'ENTY'],
#  ['ind What video game hero do some of his fans call Chomper ?', 'HUM'],
#  ['count How many holes are there in a tenpin bowling ball ?', 'NUM'],
#  ['word What is the longest word in the English language ?', 'ENTY'],
#  ['other In What city or state do the most gay men live in ?', 'LOC'],
#  ["ind What TV comediennes 's characters include former movie star Nora Desmond , secretary Mrs. Wiggins and a housewife named Eunice ?",
#   'HUM'],
#  ["animal What is `` the bear of beers '' ?", 'ENTY'],
#  ['other Name the operating system that runs on IBM-compatible machines .',
#   'ENTY'],
#  ["def What does the name `` Justin '' mean ?", 'DESC'],
#  ['perc What percentage of the body is muscle ?', 'NUM'],
#  ['color What color of dry wine should be served with veal roasts and chops ?',
#   'ENTY'],
#  ['substance What is a golf ball made of ?', 'ENTY'],
#  ['def What is the Amish religion ?', 'DESC'],
#  ['money What does an average daycare provider get paid in New England ?',
#   'NUM'],
#  ['gr What was the name of the 187s Irish terrorist group in Pennsylvania mining areas ?',
#   'HUM'],
#  ['ind Who played the Ringo Kid in the 1939 film Stagecoach ?', 'HUM'],
#  ['ind Who died 1 feet from where John F. Kennedy did ?', 'HUM'],
#  ["def What is the `` coppertop '' battery ?", 'DESC'],
#  ['symbol What sign is The Water Carrier the zodiacal symbol for ?', 'ENTY'],
#  ['animal What animals do you find in the stock market ?', 'ENTY'],
#  ['def What is color ?', 'DESC'],
#  ['date When is the site www.questions.com going to open ?', 'NUM'],
#  ['cremat What did Shostakovich write for Rostropovich ?', 'ENTY'],
#  ['ind What first name was Nipsy Russell given at birth ?', 'HUM'],
#  ['manner How can I get some free technical information on Electric Vehicle ?',
#   'DESC'],
#  ['ind Who is the youngest of the Beatles ?', 'HUM'],
#  ['manner How did shipyard inspector James J. Kilroy designate equipment as being satisfactory ?',
#   'DESC'],
#  ['def What is a Jellicle Cat ?', 'DESC'],
#  ['other Where can I find the best free evidence for debate about Russia ?',
#   'LOC'],
#  ['other What is Bill Gates of Microsoft E-mail address ?', 'LOC'],
#  ['substance What is the second hardest substance ?', 'ENTY'],
#  ['reason Why did several San Diego schools stop serving apples to students ?',
#   'DESC'],
#  ['city What Russian city boasts the Hermitage Museum ?', 'LOC'],
#  ['date When is Bastille Day ?', 'NUM'],
#  ['reason What makes a tornado turn ?', 'DESC'],
#  ['count How many shots can a stock M16 hold ?', 'NUM'],
#  ['color What two colors are you blind to if you suffer from protanopia ?',
#   'ENTY'],
#  ["reason Why do n't you guys have some sort of contest where you ask a question and whoever finds the answers wins a prize ?",
#   'DESC'],
#  ['desc Who is Coronado ?', 'HUM'],
#  ['cremat What was the name of the movie that starred Sharon Stone and Arnold Schwarzenegger ?',
#   'ENTY'],
#  ['def What is artificial intelligence ?', 'DESC'],
#  ['food What do flatfish eat ?', 'ENTY'],
#  ['ind Who was the first Holy Roman Emperor ?', 'HUM'],
#  ['other What can I use to remove the stubborn gummed labels from some diskettes ?',
#   'ENTY'],
#  ['date What day of the week sees the most fatal car accidents ?', 'NUM'],
#  ['desc What is the origin of the word , magic ?', 'DESC'],
#  ['sport What sport do you shag flies in ?', 'ENTY'],
#  ['def What is white chocolate ?', 'DESC'],
#  ['other Where is Trinidad ?', 'LOC'],
#  ['gr Name the organization that is presided by a Security Council .', 'HUM'],
#  ["ind Who graced the airwaves with such pearls as `` Do ya lo-o-ove me ? Get naked , baby ! '' ?",
#   'HUM'],
#  ['food What kind of wine is Spumante ?', 'ENTY'],
#  ['ind Who portrayed portly criminologist Carl Hyatt on Checkmate ?', 'HUM'],
#  ['termeq How do you say I love you in Spanish ?', 'ENTY'],
#  ['def What does the name Gina mean ?', 'DESC'],
#  ['product What is the most advanced handheld calculator in the world ?',
#   'ENTY'],
#  ['speed How fast is light ?', 'NUM'],
#  ['termeq What is the belt of low pressure around the equator called ?',
#   'ENTY'],
#  ['def What are shooting stars ?', 'DESC'],
#  ['gr Whom did the Chicago Bulls beat in the 1993 championship ?', 'HUM'],
#  ['date When was the first American encyclopedia published ?', 'NUM'],
#  ["other What 's the tallest building in New York City ?", 'LOC'],
#  ["manner How is Easter Sunday 's date determined ?", 'DESC'],
#  ['desc What is the Motto for the State of Maryland ?', 'DESC'],
#  ['desc Who is Desmond Tutu ?', 'HUM'],
#  ['other Where can I find information on the Narragansett Indians and other tribes in Rhode Island ?',
#   'LOC'],
#  ['animal Name a tiger that is extinct .', 'ENTY'],
#  ['count How many quarters equal a pound ?', 'NUM'],
#  ["cremat What kind of books does Fodor 's publish ?", 'ENTY'],
#  ["ind What are the first names of Rowan and Martin , the stars of TV 's Laugh-In ?",
#   'HUM'],
#  ['ord What chapter of the Bible has the most verses ?', 'NUM'],
#  ['ind Who is the worst US President ever ?', 'HUM'],
#  ['ind What Asian leader was known as The Little Brown Saint ?', 'HUM'],
#  ['abb What is the abbreviated expression for the National Bureau of Investigation ?',
#   'ABBR'],
#  ['speed How fast does the fastest car go ?', 'NUM'],
#  ['mount What is the highest mountain in the world ?', 'LOC'],
#  ['other What arch can you see from the Place de la Concorde ?', 'LOC'],
#  ["ind Who sings the song `` Drink to me with thine eyes '' by Ben Johnson ?",
#   'HUM'],
#  ['period How long should a person wash their hands before they are clean ?',
#   'NUM'],
#  ['other Which way do you turn your Bic to increase the flame - clockwise or counterclockwise ?',
#   'LOC'],
#  ['country Which is the wealthiest country in the world ?', 'LOC'],
#  ['manner How can I find a phone number of someone if I only know their email address ?',
#   'DESC'],
#  ['manner How can you contact play producers and promoters on-line ?', 'DESC'],
#  ['ind Who is the monarch of the United Kingdom ?', 'HUM'],
#  ['dismed What is a fear of passing high objects ?', 'ENTY'],
#  ['desc What do players try to do when the music stops in a game of musical chairs ?',
#   'DESC'],
#  ['ind What are the top ten most common girl names in the US ?', 'HUM'],
#  ['reason Why is black the color of mourning in the West ?', 'DESC'],
#  ['other What is the rarest coin ?', 'ENTY'],
#  ['cremat What Judith Rossner novel was made into a film starring Diane Keaton ?',
#   'ENTY'],
#  ["country Which country is Australia 's largest export market ?", 'LOC'],
#  ['other Where is the Kentucky Horse Park located ?', 'LOC'],
#  ['dismed What is a fear of parasites ?', 'ENTY'],
#  ['sport In what Olympic Games did Nadia Comaneci become popular ?', 'ENTY'],
#  ['ind Who does data collection in tourism ?', 'HUM'],
#  ['ind What was the name of the daughter of the Virginia chief Powhatan that married John Rolfe ?',
#   'HUM'],
#  ['state What is the leading pecan and peanut growing state ?', 'LOC'],
#  ['desc What does a nihilist believe in ?', 'DESC'],
#  ['desc What did Richard Feynman say upon hearing he would receive the Nobel Prize in Physics ?',
#   'DESC'],
#  ['sport In what sport are these following numbers relevant', 'ENTY'],
#  ['ind Who were the four famous founders of United Artists ?', 'HUM'],
#  ['cremat What 2 statues did France give to other countries ?', 'ENTY'],
# ...
#  ['ind Who was the Democratic nominee in the American presidential election ?',
#   'HUM'],
#  ["cremat What was Connecticut 's first constitution called ?", 'ENTY'],
#  ['event What historical event happened in Dogtown in 1899 ?', 'ENTY'],
#  ['def What is being done about the millennium bug ?', 'DESC'],
#  ['reason What was the claim to fame of King Camp Gillette ?', 'DESC'],
#  ['dismed What is the most common kind of skin cancer in the U.S. ?', 'ENTY'],
#  ['def What is Olestra ?', 'DESC'],
#  ['country What Asian country has a bill of rights for cows ?', 'LOC'],
#  ['count How many fingers are used to draw a bow ?', 'NUM'],
#  ['plant What are two plants that clothes are made from ?', 'ENTY'],
#  ['date When was Hurricane Hugo ?', 'NUM'],
#  ['food What is the most heavily caffeinated soft drink ?', 'ENTY'],
#  ['ind What President-to-be was the first member of Congress to enlist following the attack on Pearl Harbor ?',
#   'HUM'],
#  ["money What was the price of Varian Associates ' vacuum products division ?",
#   'NUM'],
#  ["date When was `` the Great Depression '' ?", 'NUM'],
#  ['lang What language is mostly spoken in Brazil ?', 'ENTY'],
#  ['gr What college produced the most winning Super Bowl quarterbacks ?',
#   'HUM'],
#  ["manner How do you solve `` Rubik 's Cube '' ?", 'DESC'],
#  ['def What is prepared mustard ?', 'DESC'],
#  ['ind What classical Spanish writer warned', 'HUM'],
#  ["def What does `` antidisestablishmentarianism '' mean ?", 'DESC'],
#  ["ind What actor married John F. Kennedy 's sister ?", 'HUM'],
#  ['dismed What does a topophobic actor suffer from ?', 'ENTY'],
#  ['ind Who fired Maria Ybarra from her position in San Diego council ?',
#   'HUM'],
#  ['period The italian artist , Maurizio Pellegrin , is how old ?', 'NUM'],
#  ['other What type of hunting are retrievers used for ?', 'ENTY'],
#  ['reason What is Colin Powell best known for ?', 'DESC'],
#  ['ind Who was the first black golfer to tee off in the Masters ?', 'HUM'],
#  ["city What city is the setting for Puccini 's opera La Boheme ?", 'LOC'],
#  ['ind What U.S. President showed a fondness for munching on bee pollen bars ?',
#   'HUM'],
#  ['def What is measured in curies ?', 'DESC'],
#  ['ind Whose cover is that of an employee of Universal Import and Export ?',
#   'HUM'],
#  ["ind What former president 's daughter has written a book titled Murder in the White House ?",
#   'HUM'],
#  ["ind What fictional character is known as the `` melancholy Dane '' ?",
#   'HUM'],
#  ['product Italy is the largest producer of what ?', 'ENTY'],
#  ['ind What longtime game show host dropped dead while jogging in Central Park in 1984 ?',
#   'HUM'],
#  ["def What is the meaning of W.B. Yeat 's poem , `` The Three Hermits ? ''",
#   'DESC'],
#  ["ind Who were the `` filthiest people alive ? ''", 'HUM'],
#  ["dismed What infectious disease is the world 's deadliest ?", 'ENTY'],
#  ['def What is Spumante ?', 'DESC'],
#  ['date In what year did Ireland elect its first woman president ?', 'NUM'],
#  ['def What is an isthmus ?', 'DESC'],
#  ['animal What was the name of the orca that died of a fungal infection ?',
#   'ENTY'],
#  ['other Where is Mozambique located ?', 'LOC'],
#  ["animal What is Mississippi 's state animal ?", 'ENTY'],
#  ["desc What 's the origin of the word ` news ' ?", 'DESC'],
#  ['other What did Dan Aykroyd and John Belushi quit Saturday Night Live to become ?',
#   'ENTY'],
#  ['count How many months does a normal human pregnancy last ?', 'NUM'],
#  ['manner How do fuel injectors work ?', 'DESC'],
#  ["manner How can your school march in the Macy 's Thanksgiving Parade ?",
#   'DESC'],
#  ["ind What is the real name of disc jockey `` Wolfman Jack '' ?", 'HUM'],
#  ['veh What Italian liner was hijacked in 1985 ?', 'ENTY'],
#  ['city What city houses the U.S. headquarters of Procter and Gamble ?',
#   'LOC'],
#  ["product What soap was touted as being `` for people who like people '' ?",
#   'ENTY'],
#  ['money How much was the minimum wage in 1991 ?', 'NUM'],
#  ['exp What does NAFTA stand for ?', 'ABBR'],
#  ['ind Who invented silly putty ?', 'HUM'],
#  ['gr What new middle school was built in Philadelphia , Pennsylvania last year ?',
#   'HUM'],
#  ['ind Who patented the first phonograph ?', 'HUM'],
#  ['techmeth What are some tips for building a fire in a fireplace ?', 'ENTY'],
#  ['food What do manatees eat ?', 'ENTY'],
#  ['termeq How do you say 2 in Latin ?', 'ENTY'],
#  ['cremat What were popular songs and types of songs in the 1920s ?', 'ENTY'],
#  ['count How many Vietnamese were there in the Soviet Union ?', 'NUM'],
#  ["other What is November 's birthstone ?", 'ENTY'],
#  ['def What is a Certified Nurse Midwife ?', 'DESC'],
#  ['count On average , how many miles are there to the moon ?', 'NUM'],
#  ['ind Who created private detective Philip Marlowe ?', 'HUM'],
#  ['cremat What Boris Pasternak book sold 5 , 0 copies to become the fiction best-seller of 1958 ?',
#   'ENTY'],
#  ["desc What is the origin of the expression `` tout de suite '' ?", 'DESC'],
#  ['word What is the longest English word ?', 'ENTY'],
#  ['reason What is the purpose of a car bra ?', 'DESC'],
#  ['reason What is D.B. Cooper known for ?', 'DESC'],
#  ['desc Who is Colin Powell ?', 'HUM'],
#  ['animal What species is a colt ?', 'ENTY'],
#  ['exp What is the full name of the PLO ?', 'ABBR'],
#  ['country What is the smallest country in Africa ?', 'LOC'],
#  ["ind Who coined the term NN cyberspace `` in his novel NN Neuromancer '' ?",
#   'HUM'],
#  ['event What age followed the Bronze Age ?', 'ENTY'],
#  ['title What is her profession ?', 'HUM'],
#  ['ind What is the full name of the man who invented the multicolored game cube that has 42.3 quintillion potential combinations ?',
#   'HUM'],
#  ['exp What does the word LASER mean ?', 'ABBR'],
#  ["def What does the name `` Anthony '' mean ?", 'DESC'],
#  ["ind Who was Lauren Bacall 's first husband ?", 'HUM'],
#  ['def What is a rhomboideus minor ?', 'DESC'],
#  ['count How many hands does Bjorn Borg use when hitting his forehand ?',
#   'NUM'],
#  ['count How many people died on D-Day ?', 'NUM'],
#  ['ind What U.S. Congressman said', 'HUM'],
#  ['ind Who created the character of Scrooge ?', 'HUM'],
#  ['other What is the student population at the University of Massachusetts in Amherst ?',
#   'NUM'],
#  ['other Where is Windsor Castle ?', 'LOC'],
#  ['date When did the Dow first reach ?', 'NUM'],
#  ['reason Why were people recruited for the Vietnam War ?', 'DESC'],
#  ['gr What party was Winston Churchill a member of ?', 'HUM'],
#  ["gr What American League baseball team 's worst finish between 1926 and 1964 was fourth ?",
#   'HUM'],
#  ['other Where can I find the names of all the 15 Pokemon ?', 'LOC'],
#  ['state What state does Martha Stewart live in ?', 'LOC'],
#  ['animal Which killer whale died at Sea World of a fungal infection ?',
#   'ENTY'],
#  ['country What are the Benelux countries ?', 'LOC'],
#  ["other Where 's the Petrified Forest ?", 'LOC'],
#  ['lang What is a language spoken by the Sioux ?', 'ENTY'],
#  ['other Where is Tornado Alley ?', 'LOC'],
#  ["ind Who was the author of `` John Brown 's Body '' ?", 'HUM'],
#  ['ind What American poet wrote', 'HUM'],
#  ['state What state in the U.S. has the most blacks ?', 'LOC'],
#  ['reason Why are electric cars less efficient in the northeast than in California ?',
#   'DESC'],
#  ['title What was the occupation of Mandy Rice-Davies ?', 'HUM'],
#  ['city What is the city in which Maurizio Pellegrin lives called ?', 'LOC'],
#  ['ind Who painted the Sistine Chapel ?', 'HUM'],
#  ['ind Name the various costumed personas of Dr. Henry Pym .', 'HUM'],
#  ["animal What breed of dog was the `` Little Rascals '' dog ?", 'ENTY'],
#  ['desc What are the living conditions in Cuba ?', 'DESC'],
#  ['color What color are school buses ?', 'ENTY'],
#  ['other What is the oldest website on the Internet ?', 'LOC'],
#  ['event What events happened January 26 , 1978 ?', 'ENTY'],
#  ['ind What explorers followed Columbus to the Americas ?', 'HUM'],
#  ["ind Who is actress Goldie Hawn 's current actor boyfriend ?", 'HUM'],
#  ['ind Who banned Peter Rose from baseball for betting on games ?', 'HUM'],
#  ['def What are the seven virtues ?', 'DESC'],
#  ["termeq What other name were the `` Little Rascals '' known as ?", 'ENTY'],
#  ['date When was the San Francisco fire ?', 'NUM'],
#  ['dismed What is a fear of food ?', 'ENTY'],
#  ['count How many casinos are in Atlantic City , NJ ?', 'NUM'],
#  ['date What year did the Vietnam War end ?', 'NUM'],
#  ["ind What are the names of Richard Nixon 's two daughters ?", 'HUM'],
#  ["word What 's the word for broken glass or sharp rocks embedded in cement on top of a wall ?",
#   'ENTY'],
#  ['count What is the chromosome number of an elephant ?', 'NUM'],
#  ['gr What organization was founded by the Rev. Jerry Falwell ?', 'HUM'],
#  ["other What 's the longest river in the world ?", 'LOC'],
#  ['food Which soft drink does Madonna advertise for ?', 'ENTY'],
#  ['gr What company is being bought by Yahoo and how much is the deal worth ?',
#   'HUM'],
#  ["date When was Berlin 's Brandenburg gate erected ?", 'NUM'],
#  ['count How many double-word-score spaces are there on a Scrabble Crossword Game board ?',
#   'NUM'],
#  ['date What year did Germany sign its nonaggression pact with the Soviet Union ?',
#   'NUM'],
#  ['mount What mountain range is traversed by the highest railroad in the world ?',
#   'LOC'],
#  ["reason Why were the American soldiers in WWI called `` Doughboys ''",
#   'DESC'],
#  ['ind Who was nicknamed The Little Corporal ?', 'HUM'],
#  ['count How many CDs has Garth Brooks sold ?', 'NUM'],
#  ['veh Name the vessel used by the Atari Force in the DC comics .', 'ENTY'],
#  ['other Where are the leading medical groups specializing in lung diseases ?',
#   'LOC'],
#  ['manner How can I find online spelling , and punctuation drills for my 6th grader ?',
#   'DESC'],
#  ["other What 's the sacred river of India ?", 'LOC'],
#  ["country What is Stefan Edberg 's native country ?", 'LOC'],
#  ['body What is the only gland in humans that can regenerate itself ?',
#   'ENTY'],
#  ['count How many Gutenberg Bibles are there ?', 'NUM'],
#  ['country Name the largest country in South America .', 'LOC'],
#  ['event What astronomical phenomenon takes place in Jan. 1999 ?', 'ENTY'],
#  ['desc What information can you get me on Fairground Park in St. Louis',
#   'DESC'],
#  ["ind What was American folk hero John Chapman 's nickname ?", 'HUM'],
#  ['desc What is the difference between a median and a mean ?', 'DESC'],
#  ['cremat What was the top box office movie in April 1998 ?', 'ENTY'],
#  ['reason What makes thunder ?', 'DESC'],
#  ["ind What author did photographer Yousuf Karsh call `` the shiest man I ever met '' ?",
#   'HUM'],
#  ['other Which is the largest clock , diameter wise , in Europe ?', 'ENTY'],
#  ['plant What plant is rum made from ?', 'ENTY'],
#  ['country What country are Godiva chocolates from ?', 'LOC'],
#  ['ind Name the poet of the poem which begins', 'HUM'],
#  ['food Which condiment was once sold as a patent medicine ?', 'ENTY'],
#  ['state What U.S. state records the least rainfall ?', 'LOC'],
#  ['reason Why did the world enter a global depression in 1929 ?', 'DESC'],
#  ['def What was archy , and mehitabel ?', 'DESC'],
#  ["city What Texas city got its name from the Spanish for `` yellow '' ?",
#   'LOC'],
#  ['substance What are the chemicals used in glowsticks ?', 'ENTY'],
#  ['country What country did the Nile River originate in ?', 'LOC'],
#  ['color What color are tennis balls ?', 'ENTY'],
#  ['ind What barroom judge called himself The Law West of the Pecos ?', 'HUM'],
#  ['desc What excuse did the NATO people give for hitting the Chinese embassy ?',
#   'DESC'],
#  ['ind Who was President of Costa Rica in 1994 ?', 'HUM'],
#  ['sport What sports event is Meyer Wolfsheim supposed to have fixed in The Great Gatsby ?',
#   'ENTY'],
#  ['country What country has the best defensive position in the board game Diplomacy ?',
#   'LOC'],
#  ['country What two countries share the Khyber Pass ?', 'LOC'],
#  ['ind Who was chairman of the Senate select committee that tried to get to the bottom of Watergate ?',
#   'HUM'],
#  ['desc What is the origin of the surname of Braun ?', 'DESC'],
#  ['sport What card game has variations called Canfield , Klondike and Spider ?',
#   'ENTY'],
#  ['def What is Australia Day ?', 'DESC'],
#  ["animal What mammal of North America is the world 's longest-lived for its size ?",
#   'ENTY'],
#  ['def What was the Chivington Massacre ?', 'DESC'],
#  ["ind What actor starred in 1980 's Blue Lagoon , 1982 's The Pirate Movie and 1983 's A Night in Heaven ?",
#   'HUM'],
#  ['count How many home runs did Lou Gehrig have during his career ?', 'NUM'],
#  ['city In what city is the headquarters of Sinn Fein ?', 'LOC'],
#  ['other Where can I find information on George Bush ?', 'LOC'],
#  ['ind Who is the voice of Miss Piggy ?', 'HUM'],
#  ['termeq What is the dialogue circle in cartoons called ?', 'ENTY'],
#  ['def What does the word camaro mean , from the GM car the Camaro ?', 'DESC'],
#  ['ind Who replaced Bert Parks as the host of The Miss America Pageant ?',
#   'HUM'],
#  ["count How many boys play the game in Winslow Homer 's 1872 painting Snap the Whip ?",
#   'NUM'],
#  ['def What is the AIM-54C Phoenix ?', 'DESC'],
#  ['date When are sheep shorn ?', 'NUM'],
#  ['sport What sport is Chris Jogis a top player of ?', 'ENTY'],
#  ["other What 's the second-largest island in the world ?", 'LOC'],
#  ['def What is the definition of low island ?', 'DESC'],
#  ['date What century does Captain Video live in ?', 'NUM'],
#  ['other What types of water pollution are there ?', 'ENTY'],
#  ['count How many astronauts manned each Project Mercury flight ?', 'NUM'],
#  ['food What soft drink would provide me with the biggest intake of caffeine ?',
#   'ENTY'],
#  ["other What 's the name of a golf course in Myrtle Beach ?", 'ENTY'],
#  ['event What are some of the significant historical events of the 1990s ?',
#   'ENTY'],
#  ['cremat Name the only extant trilogy of classical Greek plays .', 'ENTY'],
#  ['other Where is Logan Airport ?', 'LOC'],
#  ['desc What is the difference between Neoclassical art and Romanticism art ?',
#   'DESC'],
#  ['ind Who was the first person inducted into the U.S. Swimming Hall of Fame ?',
#   'HUM'],
#  ['ind What golfer has been called Ohio Fats and Blobbo ?', 'HUM'],
#  ['ind Who murdered Leno and Rosemary LaBianca on August 1', 'HUM'],
#  ['money What is the average cost for four years of medical school ?', 'NUM'],
#  ['other What does God create in the first sentence of the Bible ?', 'ENTY'],
#  ['ind Which of the following men was not married to Rita Hayworth ?', 'HUM'],
#  ['money What is the current ticket fare from from Cairo to Barbados ?',
#   'NUM'],
#  ['exp What does NN O `` mean when used as a prefix in Irish surnames ?',
#   'ABBR'],
#  ['manner How do you find oxidation numbers ?', 'DESC'],
#  ['state What is the state nickname of Mississippi ?', 'LOC'],
#  ['reason What is Black Hills , South Dakota most famous for ?', 'DESC'],
#  ['cremat What 1966 boob tube bomb took astronauts back to prehistoric times ?',
#   'ENTY'],
#  ['count How many students attend the University of Massachusetts ?', 'NUM'],
#  ["ind Who said , `` I shall return . '' during World War Two ?", 'HUM'],
#  ['event What holidays are celebrated in Ireland ?', 'ENTY'],
#  ['ind Who portrayed Etta Place , companion to Butch Cassidey and the Sundance Kid ?',
#   'HUM'],
#  ['def What are the Greek numerals ?', 'DESC'],
#  ["other What 's the name of the temple that is located near the capital city of Laos ?",
#   'LOC'],
#  ['dismed What is a fear of sleep ?', 'ENTY'],
#  ['sport What auto race was Wilbur Reed the first to win three times ?',
#   'ENTY'],
#  ['animal What are the most common breeding birds in the U.S. ?', 'ENTY'],
#  ["event What was organized as a Confederate veterans ' social club in Pulaski , in Tennessee , in 1866 ?",
#   'ENTY'],
#  ['manner How do you look up criminal records on the Internet ?', 'DESC'],
#  ['other Where is the actress , Marion Davies , buried ?', 'LOC'],
#  ['desc What is an example of an actual case of using the Fourteenth Amendment ?',
#   'DESC'],
#  ['ind Who was the Charlie perfume woman ?', 'HUM'],
#  ["ind Who portrayed `` Rosanne Rosanna-Dana '' on the television show `` Saturday Night Live '' ?",
#   'HUM']]

# %%
X, y = list(zip(*data))

# %%
X[:2]
# Out:
# ('manner How did serfdom develop in and then leave Russia ?',
#  'cremat What films featured the character Popeye Doyle ?')

# %%
y[:2]
# Out:
# ('DESC', 'ENTY')

# %%
X = list(X)

# %%
X[:2]
# Out:
# ['manner How did serfdom develop in and then leave Russia ?',
#  'cremat What films featured the character Popeye Doyle ?']

# %%
for i, x in enumerate(X):
    X[i] = re.sub('\d', '#', x).split()

# %%
X[:5]
# Out:
# [['manner',
#   'How',
#   'did',
#   'serfdom',
#   'develop',
#   'in',
#   'and',
#   'then',
#   'leave',
#   'Russia',
#   '?'],
#  ['cremat',
#   'What',
#   'films',
#   'featured',
#   'the',
#   'character',
#   'Popeye',
#   'Doyle',
#   '?'],
#  ['manner',
#   'How',
#   'can',
#   'I',
#   'find',
#   'a',
#   'list',
#   'of',
#   'celebrities',
#   "'",
#   'real',
#   'names',
#   '?'],
#  ['animal',
#   'What',
#   'fowl',
#   'grabs',
#   'the',
#   'spotlight',
#   'after',
#   'the',
#   'Chinese',
#   'Year',
#   'of',
#   'the',
#   'Monkey',
#   '?'],
#  ['exp', 'What', 'is', 'the', 'full', 'form', 'of', '.com', '?']]

# %%
flatten(X[:5])
# Out:
# ['manner',
#  'How',
#  'did',
#  'serfdom',
#  'develop',
#  'in',
#  'and',
#  'then',
#  'leave',
#  'Russia',
#  '?',
#  'cremat',
#  'What',
#  'films',
#  'featured',
#  'the',
#  'character',
#  'Popeye',
#  'Doyle',
#  '?',
#  'manner',
#  'How',
#  'can',
#  'I',
#  'find',
#  'a',
#  'list',
#  'of',
#  'celebrities',
#  "'",
#  'real',
#  'names',
#  '?',
#  'animal',
#  'What',
#  'fowl',
#  'grabs',
#  'the',
#  'spotlight',
#  'after',
#  'the',
#  'Chinese',
#  'Year',
#  'of',
#  'the',
#  'Monkey',
#  '?',
#  'exp',
#  'What',
#  'is',
#  'the',
#  'full',
#  'form',
#  'of',
#  '.com',
#  '?']

# %%
vocab = list(set(flatten(X)))

# %%
len(vocab)
# Out:
# 2846

# %%
len(set(y)) # num of class
# Out:
# 6

# %%
word2index={'<PAD>': 0, '<UNK>': 1}

for vo in vocab:
    if word2index.get(vo) is None:
        word2index[vo] = len(word2index)

# %%
word2index
# Out:
# {'<PAD>': 0,
#  '<UNK>': 1,
#  'Renoir': 2,
#  'Gatsby': 3,
#  'Alvin': 4,
#  'recorded': 5,
#  'level': 6,
#  'Dane': 7,
#  'drills': 8,
#  'advertizing': 9,
#  'Democratic': 10,
#  'fare': 11,
#  'Janelle': 12,
#  'def': 13,
#  'tokens': 14,
#  'duck': 15,
#  'nicknamed': 16,
#  'Anopheles': 17,
#  'layers': 18,
#  'breeding': 19,
#  '.dbf': 20,
#  'cash-conscious': 21,
#  'Genesis': 22,
#  'mehitabel': 23,
#  'named': 24,
#  'piece': 25,
#  'bought': 26,
#  'profession': 27,
#  'Thatcher': 28,
#  'Brown': 29,
#  'National': 30,
#  'first': 31,
#  'systems': 32,
#  'cancer': 33,
#  'popcorn': 34,
#  'Dr.': 35,
#  'steel': 36,
#  'death': 37,
#  'biggest': 38,
#  'J.': 39,
#  'motto': 40,
#  'Dolphins': 41,
#  'Night': 42,
#  'colleges': 43,
#  'had': 44,
#  'total': 45,
#  'Chinese': 46,
#  'dare': 47,
#  'claim': 48,
#  'deck': 49,
#  'produced': 50,
#  'album': 51,
#  'Game': 52,
#  'two': 53,
#  'Challengers': 54,
#  'organization': 55,
#  'gold': 56,
#  'embassy': 57,
#  'where': 58,
#  'him': 59,
#  'Club': 60,
#  'Las': 61,
#  'Loop': 62,
#  'shower': 63,
#  'Internet': 64,
#  'Representatives': 65,
#  'tourists': 66,
#  'constitution': 67,
#  'office': 68,
#  'Yousuf': 69,
#  'expectant': 70,
#  'War': 71,
#  'oil': 72,
#  'superstar': 73,
#  'intercourse': 74,
#  'aged': 75,
#  'killer': 76,
#  'miles': 77,
#  'attacks': 78,
#  'seized': 79,
#  'shots': 80,
#  'shipment': 81,
#  'Khyber': 82,
#  'Will': 83,
#  'intractable': 84,
#  'chapter': 85,
#  'Family': 86,
#  'Doxat': 87,
#  'not': 88,
#  'Cash': 89,
#  'infection': 90,
#  'rivers': 91,
#  'director': 92,
#  'be': 93,
#  'characterstics': 94,
#  'contest': 95,
#  'Lifesaver': 96,
#  'December': 97,
#  'lie': 98,
#  'San': 99,
#  'declared': 100,
#  'drops': 101,
#  'longitude': 102,
#  'blush': 103,
#  'bird': 104,
#  'rail': 105,
#  'Swiss': 106,
#  'Amendment': 107,
#  'terrorist': 108,
#  'Bush': 109,
#  'Atlantic': 110,
#  'Chris': 111,
#  'birds': 112,
#  'Islands': 113,
#  'Festival': 114,
#  'Polynesian': 115,
#  'baby': 116,
#  'gymnast': 117,
#  'Yellow': 118,
#  'fossils': 119,
#  'DNA': 120,
#  'granted': 121,
#  'issue': 122,
#  '##th': 123,
#  'Tom': 124,
#  'Chapel': 125,
#  'photographer': 126,
#  'made': 127,
#  'pact': 128,
#  'Bronze': 129,
#  'young': 130,
#  'seed': 131,
#  'much': 132,
#  'war': 133,
#  'Aldrin': 134,
#  'Brandenburg': 135,
#  'cat-bear': 136,
#  'stands': 137,
#  'Entebbe': 138,
#  'international': 139,
#  'case': 140,
#  'bomb': 141,
#  'might': 142,
#  'during': 143,
#  'plant': 144,
#  'fresh': 145,
#  'run': 146,
#  'Grant': 147,
#  'hunter': 148,
#  'Alyssa': 149,
#  'voting': 150,
#  'web': 151,
#  'astronaut': 152,
#  'done': 153,
#  'discover': 154,
#  'cows': 155,
#  'chessboard': 156,
#  'Charlie': 157,
#  'several': 158,
#  'nominee': 159,
#  'Bill': 160,
#  'Stagecoach': 161,
#  'classified': 162,
#  'vacuum': 163,
#  'it': 164,
#  'permitted': 165,
#  'bet': 166,
#  'function': 167,
#  'circle': 168,
#  'silly': 169,
#  'most': 170,
#  "''": 171,
#  'arms': 172,
#  'fixed': 173,
#  'bogs': 174,
#  'Egg': 175,
#  'between': 176,
#  'cork': 177,
#  'dentist': 178,
#  'IP': 179,
#  'Moscow': 180,
#  'Pass': 181,
#  'Inch': 182,
#  'e-mail': 183,
#  'founding': 184,
#  'stand': 185,
#  'Queen': 186,
#  'territory': 187,
#  'scar-faced': 188,
#  'Rawhide': 189,
#  'Orinoco': 190,
#  'advertised': 191,
#  'are': 192,
#  'Packin': 193,
#  'How': 194,
#  'with': 195,
#  'singles': 196,
#  'islands': 197,
#  'Laos': 198,
#  'sign': 199,
#  'return': 200,
#  'directed': 201,
#  'King': 202,
#  'Joyce': 203,
#  'alone': 204,
#  'competitor': 205,
#  'harness': 206,
#  'Jellicle': 207,
#  'Pink': 208,
#  'Astaire': 209,
#  'knock': 210,
#  'online': 211,
#  'holiday': 212,
#  'cartoon': 213,
#  'www.answers.com': 214,
#  'verses': 215,
#  'musical': 216,
#  'octopus': 217,
#  'famous': 218,
#  'Bureau': 219,
#  'Americas': 220,
#  'instru': 221,
#  'trip': 222,
#  'dubbed': 223,
#  'Chest': 224,
#  'retrievers': 225,
#  'blind': 226,
#  'beer-producing': 227,
#  'redness': 228,
#  'Australia': 229,
#  'design': 230,
#  'prophet': 231,
#  'employee': 232,
#  'Eunice': 233,
#  'volsize': 234,
#  'On': 235,
#  'Crusaders': 236,
#  'than': 237,
#  'disc': 238,
#  'Blind': 239,
#  'born-child': 240,
#  'Certified': 241,
#  'ways': 242,
#  'voyage': 243,
#  'steps': 244,
#  'Define': 245,
#  'nonaggression': 246,
#  'Cleveland': 247,
#  'beethoven': 248,
#  'delivered': 249,
#  'time': 250,
#  'weakness': 251,
#  'create': 252,
#  'cents': 253,
#  'Chapman': 254,
#  'Windows': 255,
#  'Narragansett': 256,
#  'could': 257,
#  'approaching': 258,
#  'EENTY': 259,
#  'akita': 260,
#  'Watergate': 261,
#  'Southdowns': 262,
#  'put': 263,
#  'pencil': 264,
#  'Emperor': 265,
#  'languages': 266,
#  'Body': 267,
#  'Edberg': 268,
#  'select': 269,
#  'free': 270,
#  'correspondent': 271,
#  'calcium': 272,
#  'degrees': 273,
#  'Olympic': 274,
#  'cooler': 275,
#  'Caribbean': 276,
#  'waterfall': 277,
#  'write': 278,
#  'against': 279,
#  'Rica': 280,
#  'putty': 281,
#  'dreamed': 282,
#  'board': 283,
#  'perc': 284,
#  'rarest': 285,
#  'like': 286,
#  'myth': 287,
#  'Server': 288,
#  'cover': 289,
#  'nature': 290,
#  'Lee': 291,
#  'names': 292,
#  'evaporate': 293,
#  'PSI': 294,
#  'quintillion': 295,
#  'Show': 296,
#  'Lactobacillus': 297,
#  'Republic': 298,
#  'Viceroy': 299,
#  'head': 300,
#  'Wonder': 301,
#  'importer': 302,
#  'boat': 303,
#  'Who': 304,
#  'Castle': 305,
#  'course': 306,
#  'poorly': 307,
#  '``': 308,
#  'happened': 309,
#  'KnowPost.com': 310,
#  'copies': 311,
#  'enter': 312,
#  'noise': 313,
#  'global': 314,
#  'drink': 315,
#  'rate': 316,
#  'painted': 317,
#  'accessory': 318,
#  'Boxing': 319,
#  'generator': 320,
#  'crew': 321,
#  'Teddy': 322,
#  'Prize': 323,
#  'handheld': 324,
#  'ice': 325,
#  'luck': 326,
#  'recruited': 327,
#  'Bilbo': 328,
#  'occupation': 329,
#  'inch': 330,
#  'join': 331,
#  'nihilist': 332,
#  'Amish': 333,
#  'gate': 334,
#  'When': 335,
#  'technical': 336,
#  'Eriksen': 337,
#  'admonition': 338,
#  'Pope': 339,
#  'attic': 340,
#  'invented': 341,
#  'wines': 342,
#  'Get': 343,
#  'wop': 344,
#  'Garth': 345,
#  'file': 346,
#  'Sea': 347,
#  'native': 348,
#  'poet': 349,
#  'phonograph': 350,
#  'words': 351,
#  'Flight': 352,
#  'settlement': 353,
#  'advertise': 354,
#  'inside': 355,
#  'Neuromancer': 356,
#  'Lagoon': 357,
#  'industry': 358,
#  'degree': 359,
#  'considered': 360,
#  'equals': 361,
#  'CD': 362,
#  'years': 363,
#  'Vegas': 364,
#  'Monet': 365,
#  'arometherapy': 366,
#  'next': 367,
#  'what': 368,
#  'new': 369,
#  'zones': 370,
#  'Delilah': 371,
#  'trilogy': 372,
#  'using': 373,
#  'tornado': 374,
#  'clip': 375,
#  'flatfish': 376,
#  'grader': 377,
#  'Knox': 378,
#  'Sarge': 379,
#  'wood-pusher': 380,
#  'Dudley': 381,
#  'molybdenum': 382,
#  'code': 383,
#  'depression': 384,
#  'INRI': 385,
#  'name': 386,
#  'stereo': 387,
#  'bug': 388,
#  'news': 389,
#  'Jones': 390,
#  'casinos': 391,
#  'Jews': 392,
#  'hole': 393,
#  'Earth': 394,
#  'Billy': 395,
#  'Golden': 396,
#  'ship': 397,
#  'look': 398,
#  'married': 399,
#  'reach': 400,
#  'secretary': 401,
#  'Indies': 402,
#  'planted': 403,
#  'Gibson': 404,
#  'shark': 405,
#  'videotape': 406,
#  'dogs': 407,
#  "'ll": 408,
#  'County': 409,
#  'Christopher': 410,
#  'Captain': 411,
#  'ticket': 412,
#  'Hudson': 413,
#  'website': 414,
#  'Stone': 415,
#  'Russia': 416,
#  'fear': 417,
#  'Nabokov': 418,
#  'chromosome': 419,
#  'cost': 420,
#  'drive': 421,
#  'contents': 422,
#  'intelligence': 423,
#  'toll': 424,
#  'mostly': 425,
#  'airports': 426,
#  'Stein': 427,
#  'ribavirin': 428,
#  'G#': 429,
#  'annotated': 430,
#  'shot': 431,
#  'liver': 432,
#  'stardom': 433,
#  'events': 434,
#  'hits': 435,
#  'long': 436,
#  'No.#': 437,
#  'oceans': 438,
#  'Leno': 439,
#  'Buzz': 440,
#  'Wall': 441,
#  'requirements': 442,
#  'Barney': 443,
#  'saw': 444,
#  'sheep': 445,
#  'Scrabble': 446,
#  'proposition': 447,
#  'objects': 448,
#  'cells': 449,
#  'accompanying': 450,
#  'doctorate': 451,
#  'U.S.': 452,
#  'cheeks': 453,
#  'Steven': 454,
#  'Brazil': 455,
#  'share': 456,
#  'century': 457,
#  'box': 458,
#  'veterans': 459,
#  'dead': 460,
#  'owe': 461,
#  'organized': 462,
#  'The': 463,
#  'Miss': 464,
#  'Golfers': 465,
#  'techmeth': 466,
#  'Wheel': 467,
#  'Catholic': 468,
#  'Wiggins': 469,
#  'more': 470,
#  'movement': 471,
#  'born': 472,
#  'nickname': 473,
#  'Homer': 474,
#  'collect': 475,
#  'dollar': 476,
#  'Anthony': 477,
#  'elect': 478,
#  'Rosanne': 479,
#  'Michelangelo': 480,
#  'wise': 481,
#  'does': 482,
#  'coach': 483,
#  'largest': 484,
#  'troops': 485,
#  'specializing': 486,
#  'Scholar': 487,
#  'highway': 488,
#  'Jaws': 489,
#  'pollution': 490,
#  'Whip': 491,
#  'solve': 492,
#  'mutiny': 493,
#  'election': 494,
#  'government': 495,
#  'very': 496,
#  'told': 497,
#  'Monkey': 498,
#  'spoken': 499,
#  'Ocean': 500,
#  'strings': 501,
#  'chicks': 502,
#  'Johnnie': 503,
#  'song': 504,
#  'portly': 505,
#  'rights': 506,
#  'recapture': 507,
#  'companion': 508,
#  'contact': 509,
#  'Marbella': 510,
#  'season': 511,
#  'float': 512,
#  'Browns': 513,
#  'Here': 514,
#  'national': 515,
#  'era': 516,
#  'green': 517,
#  'titled': 518,
#  'Video': 519,
#  'Everest': 520,
#  'Journal': 521,
#  'Betsy': 522,
#  'State': 523,
#  'April': 524,
#  'Cat': 525,
#  'Tirana': 526,
#  'Houdini': 527,
#  'Carolina': 528,
#  '##.#': 529,
#  'involved': 530,
#  'Kimpo': 531,
#  'stranger': 532,
#  'colonies': 533,
#  'Rev.': 534,
#  'clock': 535,
#  'speaks': 536,
#  'Mormons': 537,
#  'Gamble': 538,
#  'World': 539,
#  'Ozzy': 540,
#  'percent': 541,
#  'snow': 542,
#  'quantity': 543,
#  'given': 544,
#  'Seas': 545,
#  'Seattle': 546,
#  'Super': 547,
#  'Person': 548,
#  'Helen': 549,
#  'Sleepless': 550,
#  'became': 551,
#  'Spumante': 552,
#  'apples': 553,
#  'ballots': 554,
#  'closest': 555,
#  'nonchlorine': 556,
#  'Romans': 557,
#  'International': 558,
#  'race': 559,
#  'angles': 560,
#  'gland': 561,
#  'bog': 562,
#  'original': 563,
#  'WWII': 564,
#  'occupy': 565,
#  'Emil': 566,
#  'artificial': 567,
#  'Lord': 568,
#  'London': 569,
#  'Gate': 570,
#  'titanium': 571,
#  'tried': 572,
#  'IBM-compatible': 573,
#  'detective': 574,
#  'dummy': 575,
#  'fastest': 576,
#  'down': 577,
#  'serving': 578,
#  'Ozzie': 579,
#  'bees': 580,
#  'won': 581,
#  'Riots': 582,
#  'equal': 583,
#  'Hyatt': 584,
#  'labels': 585,
#  'sink': 586,
#  'Wilson': 587,
#  'tower': 588,
#  'features': 589,
#  'Philip': 590,
#  'bottles': 591,
#  'Nepal': 592,
#  'himself': 593,
#  'Pennsylvania': 594,
#  'Kevin': 595,
#  'Prince': 596,
#  'Death': 597,
#  'tourist': 598,
#  'Baggins': 599,
#  'plural': 600,
#  'journal': 601,
#  'doesn': 602,
#  'men': 603,
#  'Romanticism': 604,
#  'hijacked': 605,
#  'energy': 606,
#  'Confederate': 607,
#  'definition': 608,
#  'Award': 609,
#  'Nails': 610,
#  'Tutu': 611,
#  'one': 612,
#  'General': 613,
#  'Hamblen': 614,
#  'Churchill': 615,
#  'de': 616,
#  'person': 617,
#  'golfing': 618,
#  'Steve': 619,
#  'perfect': 620,
#  'Malick': 621,
#  'weapon': 622,
#  'pig-the': 623,
#  'From': 624,
#  'voice': 625,
#  'NASDAQ': 626,
#  'hearts': 627,
#  'Leverkusen': 628,
#  'Virginia': 629,
#  'snoogans': 630,
#  '##-year-old': 631,
#  'January': 632,
#  'went': 633,
#  'K': 634,
#  'women': 635,
#  'Costner': 636,
#  'deadliest': 637,
#  'Scrooge': 638,
#  'thunder': 639,
#  'numbers': 640,
#  'once': 641,
#  'estate': 642,
#  'I': 643,
#  'business': 644,
#  'advanced': 645,
#  'valuable': 646,
#  'Can': 647,
#  'community': 648,
#  'bra': 649,
#  'instrument': 650,
#  'right': 651,
#  'Madonna': 652,
#  'see': 653,
#  'Tennessee': 654,
#  'subway': 655,
#  'temple': 656,
#  'deveopment': 657,
#  'Wolfman': 658,
#  'black': 659,
#  'NNP': 660,
#  'actor': 661,
#  'products': 662,
#  'gained': 663,
#  'computer': 664,
#  'Sioux': 665,
#  'colors': 666,
#  'left-handed': 667,
#  'religion': 668,
#  'Rhine': 669,
#  'British': 670,
#  'Corporal': 671,
#  'House': 672,
#  'Edwin': 673,
#  'mixable': 674,
#  'Green': 675,
#  'celebrities': 676,
#  'root': 677,
#  'island': 678,
#  'antidisestablishmentarianism': 679,
#  'West': 680,
#  'Snap': 681,
#  'just': 682,
#  'played': 683,
#  'fired': 684,
#  'birth': 685,
#  'shortest': 686,
#  'open': 687,
#  'IQ': 688,
#  'Mercury': 689,
#  'James': 690,
#  'articles': 691,
#  'Steel': 692,
#  'attend': 693,
#  'Terrific': 694,
#  'Greek': 695,
#  'inches': 696,
#  'love': 697,
#  'goddess': 698,
#  'mountain': 699,
#  'Trans': 700,
#  'covrefeu': 701,
#  'include': 702,
#  'powerful': 703,
#  'Nebraska': 704,
#  'astronomical': 705,
#  'treehouse': 706,
#  'Grenada': 707,
#  'weight': 708,
#  'cocaine': 709,
#  'questions': 710,
#  'day': 711,
#  'Johnson': 712,
#  'draws': 713,
#  'sons': 714,
#  '$##': 715,
#  'she': 716,
#  'Jayne': 717,
#  'mourning': 718,
#  'cranberry': 719,
#  'isosceles': 720,
#  'neanderthal': 721,
#  'AIM-##C': 722,
#  'battle': 723,
#  '####-###': 724,
#  'tabulates': 725,
#  'Pride': 726,
#  'money': 727,
#  'Church': 728,
#  'leader': 729,
#  'To': 730,
#  'temp': 731,
#  'division': 732,
#  'munching': 733,
#  'Disabilities': 734,
#  'North': 735,
#  'Mel': 736,
#  'airwaves': 737,
#  'book': 738,
#  'Forest': 739,
#  'Maria': 740,
#  'scares': 741,
#  'millennium': 742,
#  'Louie': 743,
#  'Paleozoic': 744,
#  'call': 745,
#  'showed': 746,
#  'less': 747,
#  'ejaculation': 748,
#  'cocktail': 749,
#  'around': 750,
#  'shrubs': 751,
#  'Horse': 752,
#  'literature': 753,
#  'ears': 754,
#  'calories': 755,
#  'current': 756,
#  'sale': 757,
#  'stock': 758,
#  'cards': 759,
#  'Canfield': 760,
#  'patented': 761,
#  'Stanford': 762,
#  'NAFTA': 763,
#  'simple': 764,
#  'enough': 765,
#  'early': 766,
#  'hackers': 767,
#  'extinct': 768,
#  'Varian': 769,
#  'for': 770,
#  'former': 771,
#  'golfer': 772,
#  'portrayed': 773,
#  'committee': 774,
#  'Columbus': 775,
#  'but': 776,
#  'fraction': 777,
#  'horse': 778,
#  'tiger': 779,
#  'Security': 780,
#  'Kilroy': 781,
#  'other': 782,
#  'was': 783,
#  'Independence': 784,
#  'doctors': 785,
#  'satisfactory': 786,
#  'zodiacal': 787,
#  'concentration': 788,
#  'correct': 789,
#  'system': 790,
#  'floods': 791,
#  'Bloom': 792,
#  'Zorro': 793,
#  'promote': 794,
#  'Lockerbie': 795,
#  'includes': 796,
#  'sacred': 797,
#  'glowsticks': 798,
#  'Landing': 799,
#  'your': 800,
#  'Peter': 801,
#  'patent': 802,
#  'extension': 803,
#  'back': 804,
#  'rites': 805,
#  'Oscar': 806,
#  'Year': 807,
#  'cucumber': 808,
#  'middle': 809,
#  'boyfriend': 810,
#  'songs': 811,
#  'Israel': 812,
#  'cars': 813,
#  'Crossword': 814,
#  'site': 815,
#  'learning': 816,
#  'million': 817,
#  'enclose': 818,
#  'provide': 819,
#  'bite': 820,
#  'lyrics': 821,
#  'auberge': 822,
#  'following': 823,
#  'Camaro': 824,
#  'virtues': 825,
#  'oxidation': 826,
#  'Colonel': 827,
#  'designate': 828,
#  'served': 829,
#  'Statue': 830,
#  'signature': 831,
#  'distinct': 832,
#  'Harriet': 833,
#  'heavily': 834,
#  'hamburgers': 835,
#  'calluses': 836,
#  'Boop': 837,
#  'use': 838,
#  'Pecos': 839,
#  'Place': 840,
#  'Goodall': 841,
#  'operating': 842,
#  'cremat': 843,
#  'Apricot': 844,
#  'Why': 845,
#  'event': 846,
#  'Spielberg': 847,
#  'developmental': 848,
#  'Piggy': 849,
#  'agency': 850,
#  'Galapagos': 851,
#  '##-??': 852,
#  'best-seller': 853,
#  'Thomas': 854,
#  'Jean': 855,
#  'read': 856,
#  'these': 857,
#  'Sharp': 858,
#  'Movie': 859,
#  'River': 860,
#  'caused': 861,
#  'New': 862,
#  'Penn': 863,
#  'March': 864,
#  'incompetent': 865,
#  'seven': 866,
#  'determined': 867,
#  'flow': 868,
#  'Pearl': 869,
#  'term': 870,
#  'tongue': 871,
#  'lung': 872,
#  'education': 873,
#  'fortune': 874,
#  'Spider-Man': 875,
#  'pollen': 876,
#  'southern': 877,
#  'after': 878,
#  'Jewish': 879,
#  'Universal': 880,
#  'stars': 881,
#  'insurance': 882,
#  'pea-soup': 883,
#  'character': 884,
#  'suite': 885,
#  'Pudding': 886,
#  'complete': 887,
#  'danced': 888,
#  'Midwife': 889,
#  'forms': 890,
#  'been': 891,
#  'wallpaper': 892,
#  'Potter': 893,
#  'daycare': 894,
#  'Barbados': 895,
#  'highest': 896,
#  'Wilbur': 897,
#  'ind': 898,
#  'F': 899,
#  'Rosemary': 900,
#  'jockey': 901,
#  'fondness': 902,
#  'foul': 903,
#  'boob': 904,
#  'Louis': 905,
#  'children': 906,
#  'Laugh-In': 907,
#  'Eiffel': 908,
#  'Sheika': 909,
#  'need': 910,
#  'Powell': 911,
#  'house': 912,
#  'qigong': 913,
#  'stop': 914,
#  'Force': 915,
#  'Depression': 916,
#  'and': 917,
#  '#th': 918,
#  'directorial': 919,
#  'alive': 920,
#  'Dorsets': 921,
#  'passenger': 922,
#  'remove': 923,
#  'elicit': 924,
#  'power': 925,
#  'Races': 926,
#  'heating': 927,
#  'Humbert': 928,
#  'minister': 929,
#  'die': 930,
#  'Yahoo': 931,
#  'moon': 932,
#  'Awards': 933,
#  'Maryland': 934,
#  'followed': 935,
#  'acted': 936,
#  'Professor': 937,
#  'isthmus': 938,
#  'presided': 939,
#  'second-largest': 940,
#  'party': 941,
#  'Parks': 942,
#  'provider': 943,
#  'Flintstones': 944,
#  'Milano': 945,
#  'commonly-spoken': 946,
#  'Zealand': 947,
#  'Space': 948,
#  'Boards': 949,
#  'Fourteenth': 950,
#  'killing': 951,
#  'Logan': 952,
#  'bank': 953,
#  'Kansas': 954,
#  'Hermits': 955,
#  'band': 956,
#  'relevant': 957,
#  'downhill': 958,
#  'chronic': 959,
#  'Fortune': 960,
#  'Judith': 961,
#  'sides': 962,
#  'E-mail': 963,
#  'failure': 964,
#  'BladeRunner': 965,
#  'rode': 966,
#  'American': 967,
#  'clean': 968,
#  'L.': 969,
#  'originate': 970,
#  'vessel': 971,
#  'beer': 972,
#  'arch-enemy': 973,
#  'III': 974,
#  'deal': 975,
#  'while': 976,
#  'protein': 977,
#  'lobster': 978,
#  'away': 979,
#  'law': 980,
#  'assassination': 981,
#  'tails': 982,
#  'S.O.S.': 983,
#  'language': 984,
#  'Reuter': 985,
#  'attractions': 986,
#  'six': 987,
#  'slowest': 988,
#  'flavor': 989,
#  'autoimmune': 990,
#  'playing': 991,
#  'athlete': 992,
#  'temperature': 993,
#  'light': 994,
#  'Alley': 995,
#  'Lakes': 996,
#  'Rain': 997,
#  'typically': 998,
#  'speak': 999,
#  ...}

# %%
index2word = {v:k for k, v in word2index.items()}

# %%
target2index = {}

for cl in set(y):
    if target2index.get(cl) is None:
        target2index[cl] = len(target2index)

index2target = {v:k for k, v in target2index.items()}

# %%
target2index
# Out:
# {'ABBR': 0, 'DESC': 1, 'ENTY': 2, 'LOC': 3, 'HUM': 4, 'NUM': 5}

# %%
list(zip(X))
# Out:
# [(['manner',
#    'How',
#    'did',
#    'serfdom',
#    'develop',
#    'in',
#    'and',
#    'then',
#    'leave',
#    'Russia',
#    '?'],),
#  (['cremat',
#    'What',
#    'films',
#    'featured',
#    'the',
#    'character',
#    'Popeye',
#    'Doyle',
#    '?'],),
#  (['manner',
#    'How',
#    'can',
#    'I',
#    'find',
#    'a',
#    'list',
#    'of',
#    'celebrities',
#    "'",
#    'real',
#    'names',
#    '?'],),
#  (['animal',
#    'What',
#    'fowl',
#    'grabs',
#    'the',
#    'spotlight',
#    'after',
#    'the',
#    'Chinese',
#    'Year',
#    'of',
#    'the',
#    'Monkey',
#    '?'],),
#  (['exp', 'What', 'is', 'the', 'full', 'form', 'of', '.com', '?'],),
#  (['ind',
#    'What',
#    'contemptible',
#    'scoundrel',
#    'stole',
#    'the',
#    'cork',
#    'from',
#    'my',
#    'lunch',
#    '?'],),
#  (['gr',
#    'What',
#    'team',
#    'did',
#    'baseball',
#    "'s",
#    'St.',
#    'Louis',
#    'Browns',
#    'become',
#    '?'],),
#  (['title', 'What', 'is', 'the', 'oldest', 'profession', '?'],),
#  (['def', 'What', 'are', 'liver', 'enzymes', '?'],),
#  (['ind',
#    'Name',
#    'the',
#    'scar-faced',
#    'bounty',
#    'hunter',
#    'of',
#    'The',
#    'Old',
#    'West',
#    '.'],),
#  (['date', 'When', 'was', 'Ozzy', 'Osbourne', 'born', '?'],),
#  (['reason',
#    'Why',
#    'do',
#    'heavier',
#    'objects',
#    'travel',
#    'downhill',
#    'faster',
#    '?'],),
#  (['ind', 'Who', 'was', 'The', 'Pride', 'of', 'the', 'Yankees', '?'],),
#  (['ind', 'Who', 'killed', 'Gandhi', '?'],),
#  (['event',
#    'What',
#    'is',
#    'considered',
#    'the',
#    'costliest',
#    'disaster',
#    'the',
#    'insurance',
#    'industry',
#    'has',
#    'ever',
#    'faced',
#    '?'],),
#  (['state',
#    'What',
#    'sprawling',
#    'U.S.',
#    'state',
#    'boasts',
#    'the',
#    'most',
#    'airports',
#    '?'],),
#  (['desc',
#    'What',
#    'did',
#    'the',
#    'only',
#    'repealed',
#    'amendment',
#    'to',
#    'the',
#    'U.S.',
#    'Constitution',
#    'deal',
#    'with',
#    '?'],),
#  (['count',
#    'How',
#    'many',
#    'Jews',
#    'were',
#    'executed',
#    'in',
#    'concentration',
#    'camps',
#    'during',
#    'WWII',
#    '?'],),
#  (['def', 'What', 'is', '``', 'Nine', 'Inch', 'Nails', "''", '?'],),
#  (['def', 'What', 'is', 'an', 'annotated', 'bibliography', '?'],),
#  (['date', 'What', 'is', 'the', 'date', 'of', 'Boxing', 'Day', '?'],),
#  (['other',
#    'What',
#    'articles',
#    'of',
#    'clothing',
#    'are',
#    'tokens',
#    'in',
#    'Monopoly',
#    '?'],),
#  (['ind', 'Name', '##', 'famous', 'martyrs', '.'],),
#  (['desc', 'What', "'s", 'the', 'Olympic', 'motto', '?'],),
#  (['desc',
#    'What',
#    'is',
#    'the',
#    'origin',
#    'of',
#    'the',
#    'name',
#    '`',
#    'Scarlett',
#    "'",
#    '?'],),
#  (['letter',
#    'What',
#    "'s",
#    'the',
#    'second-most-used',
#    'vowel',
#    'in',
#    'English',
#    '?'],),
#  (['ind', 'Who', 'was', 'the', 'inventor', 'of', 'silly', 'putty', '?'],),
#  (['other',
#    'What',
#    'is',
#    'the',
#    'highest',
#    'waterfall',
#    'in',
#    'the',
#    'United',
#    'States',
#    '?'],),
#  (['other', 'Name', 'a', 'golf', 'course', 'in', 'Myrtle', 'Beach', '.'],),
#  (['state', 'Which', 'two', 'states', 'enclose', 'Chesapeake', 'Bay', '?'],),
#  (['exp',
#    'What',
#    'does',
#    'the',
#    'abbreviation',
#    'AIDS',
#    'stand',
#    'for',
#    '?'],),
#  (['other', 'What', 'does', 'a', 'spermologer', 'collect', '?'],),
#  (['count',
#    'How',
#    'many',
#    'points',
#    'make',
#    'up',
#    'a',
#    'perfect',
#    'fivepin',
#    'bowling',
#    'score',
#    '?'],),
#  (['gr',
#    'Which',
#    'company',
#    'that',
#    'manufactures',
#    'video-game',
#    'hardware',
#    'sells',
#    'the',
#    '``',
#    'super',
#    'system',
#    "''",
#    '?'],),
#  (['count',
#    'How',
#    'many',
#    'Community',
#    'Chest',
#    'cards',
#    'are',
#    'there',
#    'in',
#    'Monopoly',
#    '?'],),
#  (['desc', 'What', 'do', 'Mormons', 'believe', '?'],),
#  (['date', 'When', 'did', 'the', 'neanderthal', 'man', 'live', '?'],),
#  (['religion',
#    'In',
#    'what',
#    'religion',
#    'was',
#    'Isis',
#    'the',
#    'nature',
#    'goddess',
#    '?'],),
#  (['other',
#    'Where',
#    'do',
#    'the',
#    'adventures',
#    'of',
#    '``',
#    'The',
#    'Swiss',
#    'Family',
#    'Robinson',
#    "''",
#    'take',
#    'place',
#    '?'],),
#  (['animal',
#    'What',
#    'relative',
#    'of',
#    'the',
#    'racoon',
#    'is',
#    'sometimes',
#    'known',
#    'as',
#    'the',
#    'cat-bear',
#    '?'],),
#  (['manner',
#    'How',
#    'can',
#    'I',
#    'register',
#    'my',
#    'website',
#    'in',
#    'Yahoo',
#    'for',
#    'free',
#    '?'],),
#  (['other',
#    'What',
#    'was',
#    'cash-conscious',
#    'Colonel',
#    'Edwin',
#    'L.',
#    'Drake',
#    'the',
#    'first',
#    'to',
#    'drill',
#    '?'],),
#  (['count',
#    'How',
#    'many',
#    'people',
#    'in',
#    'the',
#    'world',
#    'speak',
#    'French',
#    '?'],),
#  (['count',
#    'How',
#    'many',
#    'inches',
#    'over',
#    'six',
#    'feet',
#    'is',
#    'the',
#    'Venus',
#    'de',
#    'Milo',
#    '?'],),
#  (['manner',
#    'How',
#    'do',
#    'they',
#    'find',
#    'or',
#    'choose',
#    'witnesses',
#    'to',
#    'an',
#    'execution',
#    '?'],),
#  (['ind',
#    'What',
#    '####s',
#    'cowboy',
#    'star',
#    'rode',
#    'Tony',
#    'the',
#    'Wonder',
#    'Horse',
#    '?'],),
#  (['food',
#    'What',
#    'cocktail',
#    'inspired',
#    'John',
#    'Doxat',
#    'to',
#    'write',
#    'the',
#    'book',
#    'Stirred-Not',
#    'Shaken',
#    '?'],),
#  (['gr', 'What', 'ISPs', 'exist', 'in', 'the', 'Caribbean', '?'],),
#  (['manner',
#    'How',
#    'do',
#    'you',
#    'ask',
#    'a',
#    'total',
#    'stranger',
#    'out',
#    'on',
#    'a',
#    'date',
#    '?'],),
#  (['other',
#    'What',
#    'weapon',
#    'is',
#    'the',
#    'mythological',
#    'character',
#    'Apollo',
#    'most',
#    'proficient',
#    'with',
#    '?'],),
#  (['country',
#    'What',
#    'country',
#    'do',
#    'the',
#    'Galapagos',
#    'Islands',
#    'belong',
#    'to',
#    '?'],),
#  (['def', 'What', 'is', 'ethology', '?'],),
#  (['ind',
#    'Who',
#    'was',
#    'the',
#    'prophet',
#    'of',
#    'the',
#    'Muslim',
#    'people',
#    '?'],),
#  (['desc',
#    'Where',
#    'did',
#    'the',
#    'term',
#    '``',
#    '##ed',
#    "''",
#    'come',
#    'from',
#    '?'],),
#  (['ind', 'Who', 'is', 'Snoopy', "'s", 'arch-enemy', '?'],),
#  (['def', 'What', 'is', 'the', 'nature', 'of', 'learning', '?'],),
#  (['color',
#    'What',
#    "'s",
#    'the',
#    'only',
#    'color',
#    'Johnny',
#    'Cash',
#    'wears',
#    'on',
#    'stage',
#    '?'],),
#  (['termeq', 'What', "'s", 'the', 'term', 'for', 'a', 'young', 'fox', '?'],),
#  (['state', 'What', 'U.S.', 'state', 'lived', 'under', 'six', 'flags', '?'],),
#  (['def', 'What', 'is', 'the', 'Kashmir', 'issue', '?'],),
#  (['other', 'Where', 'is', 'the', 'Loop', '?'],),
#  (['def',
#    'What',
#    'does',
#    '``',
#    'extended',
#    'definition',
#    "''",
#    'mean',
#    'and',
#    'how',
#    'would',
#    'one',
#    'write',
#    'a',
#    'paper',
#    'on',
#    'it',
#    '?'],),
#  (['country', 'What', 'country', "'s", 'capital', 'is', 'Tirana', '?'],),
#  (['def', 'What', 'is', 'titanium', '?'],),
#  (['ind',
#    'Who',
#    'do',
#    'Herb',
#    'and',
#    'Tootsie',
#    'live',
#    'next',
#    'door',
#    'to',
#    '?'],),
#  (['city',
#    'Which',
#    'city',
#    'has',
#    'the',
#    'oldest',
#    'relationship',
#    'as',
#    'a',
#    'sisterðcity',
#    'with',
#    'Los',
#    'Angeles',
#    '?'],),
#  (['def', 'What', 'is', 'a', 'caldera', '?'],),
#  (['reason', 'Why', 'do', 'people', 'get', 'calluses', '?'],),
#  (['other',
#    'What',
#    'are',
#    'the',
#    'names',
#    'of',
#    'the',
#    'tourist',
#    'attractions',
#    'in',
#    'Reims',
#    '?'],),
#  (['reason',
#    'What',
#    'are',
#    'Cushman',
#    'and',
#    'Wakefield',
#    'known',
#    'for',
#    '?'],),
#  (['other',
#    'What',
#    'body',
#    'of',
#    'water',
#    'does',
#    'the',
#    'Danube',
#    'River',
#    'flow',
#    'into',
#    '?'],),
#  (['ind', 'Who', 'is', 'the', 'founder', 'of', 'Scientology', '?'],),
#  (['other',
#    'What',
#    'does',
#    'the',
#    'six-footed',
#    'Musca',
#    'domestica',
#    'become',
#    'when',
#    'it',
#    'enters',
#    'a',
#    'house',
#    '?'],),
#  (['desc', 'What', 'is', 'the', 'history', 'of', 'skateboarding', '?'],),
#  (['ind',
#    'Who',
#    'starred',
#    'in',
#    'Singing',
#    'in',
#    'the',
#    'Rain',
#    'and',
#    'The',
#    'Singing',
#    'Nun',
#    '?'],),
#  (['manner',
#    'How',
#    'do',
#    'I',
#    'make',
#    'fuel',
#    'bricks',
#    'from',
#    'recycled',
#    'newspaper',
#    '?'],),
#  (['ind',
#    'What',
#    '##th-century',
#    'painter',
#    'died',
#    'in',
#    'the',
#    'Marquesas',
#    'Islands',
#    '?'],),
#  (['body',
#    'The',
#    'corpus',
#    'callosum',
#    'is',
#    'in',
#    'what',
#    'part',
#    'of',
#    'the',
#    'body',
#    '?'],),
#  (['manner',
#    'How',
#    'do',
#    'I',
#    'log',
#    'on',
#    'to',
#    'home',
#    'page',
#    'at',
#    'Headquarters',
#    'U.S.',
#    'European',
#    'Command',
#    '?'],),
#  (['country',
#    'What',
#    'country',
#    'did',
#    'the',
#    'Nazis',
#    'occupy',
#    'for',
#    '#',
#    ',',
#    'CD',
#    'NNS',
#    'IN',
#    'NNP',
#    'NNP',
#    'NNP',
#    '.'],),
#  (['other',
#    'What',
#    'is',
#    'Nebraska',
#    "'s",
#    'most',
#    'valuable',
#    'resource',
#    '?'],),
#  (['count',
#    'How',
#    'many',
#    'species',
#    'of',
#    'the',
#    'Great',
#    'White',
#    'shark',
#    'are',
#    'there',
#    '?'],),
#  (['desc', 'What', 'is', 'the', 'origin', 'of', 'head', 'lice', '?'],),
#  (['state',
#    'What',
#    'is',
#    'the',
#    'nickname',
#    'for',
#    'the',
#    'state',
#    'of',
#    'Mississippi',
#    '?'],),
#  (['animal', 'What', 'was', 'the', 'first', 'domesticated', 'bird', '?'],),
#  (['count',
#    'How',
#    'many',
#    'villi',
#    'are',
#    'found',
#    'in',
#    'the',
#    'small',
#    'intestine',
#    '?'],),
#  (['country', 'What', 'country', 'did', 'King', 'Wenceslas', 'rule', '?'],),
#  (['dismed', 'What', 'is', 'a', 'fear', 'of', 'shadows', '?'],),
#  (['ind', 'Who', 'were', 'the', 'five', 'Marx', 'brothers', '?'],),
#  (['date',
#    'In',
#    'which',
#    'year',
#    'was',
#    'New',
#    'Zealand',
#    'excluded',
#    'from',
#    'the',
#    'ANZUS',
#    'alliance',
#    '?'],),
#  (['date', 'When', 'did', 'CNN', 'begin', 'broadcasting', '?'],),
#  (['reason',
#    'What',
#    'causes',
#    'the',
#    'body',
#    'to',
#    'shiver',
#    'in',
#    'cold',
#    'temperatures',
#    '?'],),
#  (['def', 'What', 'are', 'bear', 'and', 'bull', 'markets', '?'],),
#  (['cremat',
#    'What',
#    'J.R.R.',
#    'Tolkien',
#    'book',
#    'features',
#    'Bilbo',
#    'Baggins',
#    'as',
#    'the',
#    'central',
#    'character',
#    '?'],),
#  (['def', 'What', 'is', '``', 'dew', 'point', "''", '?'],),
#  (['def', 'What', 'is', 'the', 'meaning', 'of', 'Jesus', '?'],),
#  (['gr',
#    'What',
#    'company',
#    "'s",
#    'logo',
#    'is',
#    'a',
#    '``',
#    'W',
#    "''",
#    'in',
#    'a',
#    'circle',
#    '?'],),
#  (['def', 'What', 'is', 'the', 'definition', 'of', 'a', 'cascade', '?'],),
#  (['date',
#    'When',
#    'did',
#    'Rococo',
#    'painting',
#    'and',
#    'architecture',
#    'flourish',
#    '?'],),
#  (['country',
#    'What',
#    'country',
#    "'s",
#    'national',
#    'passenger',
#    'rail',
#    'system',
#    'is',
#    'called',
#    'Via',
#    '?'],),
#  (['ind', 'Who', 'invented', 'Make-up', '?'],),
#  (['desc',
#    'What',
#    'is',
#    'the',
#    'origin',
#    'of',
#    'the',
#    'word',
#    '``',
#    'attic',
#    "''",
#    '?'],),
#  (['desc',
#    'What',
#    'did',
#    'Delilah',
#    'do',
#    'to',
#    'Samson',
#    "'s",
#    'hair',
#    '?'],),
#  (['animal',
#    'What',
#    'kind',
#    'of',
#    'animals',
#    'were',
#    'in',
#    'the',
#    'Paleozoic',
#    'era',
#    '?'],),
#  (['ind',
#    'Which',
#    'of',
#    'the',
#    'following',
#    'was',
#    'Rhodes',
#    'Scholar',
#    '?'],),
#  (['ind',
#    'Who',
#    'comprised',
#    'the',
#    'now-defunct',
#    'comic',
#    'book',
#    'team',
#    'known',
#    'as',
#    'the',
#    'Champions',
#    '?'],),
#  (['manner', 'How', 'do', 'you', 'make', 'a', 'paintball', '?'],),
#  (['state', 'What', 'U.S.', 'state', 'is', 'Fort', 'Knox', 'in', '?'],),
#  (['animal', 'What', 'is', 'a', 'female', 'rabbit', 'called', '?'],),
#  (['mount', 'Where', 'is', 'the', 'highest', 'point', 'in', 'Japan', '?'],),
#  (['desc', 'Where', 'do', 'chihuahuas', 'come', 'from', '?'],),
#  (['other',
#    'Where',
#    'does',
#    'Barney',
#    'Rubble',
#    'go',
#    'to',
#    'work',
#    'after',
#    'he',
#    'drops',
#    'Fred',
#    'off',
#    'in',
#    'the',
#    '``',
#    'Flintstones',
#    "''",
#    'cartoon',
#    'series',
#    '?'],),
#  (['other', 'What', 'are', 'the', 'world', "'s", 'four', 'oceans', '?'],),
#  (['cremat',
#    'What',
#    "'s",
#    'the',
#    'only',
#    'work',
#    'by',
#    'Michelangelo',
#    'that',
#    'bears',
#    'his',
#    'signature',
#    '?'],),
#  (['animal',
#    'What',
#    'is',
#    'the',
#    'largest',
#    'snake',
#    'in',
#    'the',
#    'world',
#    '?'],),
#  (['cremat',
#    'In',
#    'what',
#    'medium',
#    'is',
#    'Stuart',
#    'Hamblen',
#    'considered',
#    'to',
#    'be',
#    'the',
#    'first',
#    'singing',
#    'cowboy',
#    '?'],),
#  (['other',
#    'Where',
#    'on',
#    'the',
#    'Internet',
#    'can',
#    'I',
#    'find',
#    'a',
#    'song',
#    'lyrics',
#    'database',
#    'similar',
#    'to',
#    'the',
#    'International',
#    'Lyrics',
#    'Server',
#    '?'],),
#  (['money',
#    'How',
#    'much',
#    'money',
#    'does',
#    'a',
#    'back',
#    'injury',
#    'lawsuit',
#    'get',
#    '?'],),
#  (['termeq',
#    'What',
#    "'s",
#    'the',
#    'common',
#    'name',
#    'for',
#    'acetylsalicylic',
#    'acid',
#    '?'],),
#  (['def',
#    'What',
#    'does',
#    'the',
#    'Georgetown',
#    '``',
#    'Hoya',
#    "''",
#    'mean',
#    '?'],),
#  (['other',
#    'Where',
#    'can',
#    'I',
#    'find',
#    'a',
#    'list',
#    'of',
#    '``',
#    'classic',
#    "''",
#    'books',
#    '#th',
#    'and',
#    '#th',
#    'graders',
#    'should',
#    'read',
#    '?'],),
#  (['product',
#    'Which',
#    'two',
#    'products',
#    'use',
#    'a',
#    'tiger',
#    'as',
#    'their',
#    'symbol',
#    '?'],),
#  (['manner',
#    'How',
#    'is',
#    'the',
#    'election',
#    'of',
#    'a',
#    'new',
#    'Pope',
#    'announced',
#    'to',
#    'the',
#    'world',
#    '?'],),
#  (['period',
#    'How',
#    'long',
#    'does',
#    'it',
#    'take',
#    'for',
#    'your',
#    'blood',
#    'to',
#    'make',
#    'one',
#    'complete',
#    'trip',
#    'through',
#    'the',
#    'body',
#    '?'],),
#  (['manner', 'How', 'do', 'chickens', 'have', 'baby', 'chicks', '?'],),
#  (['desc',
#    'What',
#    'is',
#    'the',
#    'historical',
#    'relationship',
#    'of',
#    'Catholic',
#    'Church',
#    'and',
#    'bingo',
#    '?'],),
#  (['manner', 'How', 'was', 'the', 'element', 'calcium', 'named', '?'],),
#  (['ind',
#    'What',
#    'crooner',
#    'joined',
#    'The',
#    'Andrews',
#    'Sisters',
#    'for',
#    'Pistol',
#    'Packin',
#    'Mama',
#    '?'],),
#  (['gr',
#    'What',
#    'piano',
#    'company',
#    'claims',
#    'its',
#    'product',
#    'is',
#    'the',
#    '``',
#    'Instrument',
#    'of',
#    'the',
#    'immortals',
#    "''",
#    '?'],),
#  (['date', 'When', 'did', 'the', 'Bounty', 'mutiny', 'take', 'place', '?'],),
#  (['cremat',
#    'What',
#    'novel',
#    'inspired',
#    'the',
#    'movie',
#    'BladeRunner',
#    '?'],),
#  (['def', 'What', 'is', 'a', 'transistor', '?'],),
#  (['cremat', 'What', 'is', 'a', 'film', 'starring', 'Jude', 'Law', '?'],),
#  (['animal',
#    'What',
#    'Hollywood',
#    'dog',
#    'died',
#    'in',
#    'the',
#    'arms',
#    'of',
#    'Jean',
#    'Harlow',
#    'in',
#    '####',
#    '?'],),
#  (['substance',
#    'What',
#    'are',
#    'the',
#    'most',
#    'common',
#    'elements',
#    'in',
#    'the',
#    'Earth',
#    "'s",
#    'crust',
#    '?'],),
#  (['money',
#    'How',
#    'much',
#    'would',
#    'it',
#    'cost',
#    'to',
#    'purchase',
#    'a',
#    '#-foot-square',
#    'party',
#    'tent',
#    ',',
#    'with',
#    'sides',
#    ',',
#    '?'],),
#  (['ind',
#    'What',
#    'actress',
#    'has',
#    'received',
#    'the',
#    'most',
#    'Oscar',
#    'nominations',
#    '?'],),
#  (['def', 'What', 'are', 'equity', 'securities', '?'],),
#  (['def', 'What', 'is', 'gymnophobia', '?'],),
#  (['count',
#    'How',
#    'many',
#    'years',
#    'do',
#    'fossils',
#    'take',
#    'to',
#    'form',
#    '?'],),
#  (['other', 'Where', 'is', 'the', 'Orinoco', '?'],),
#  (['animal',
#    'What',
#    'was',
#    'the',
#    'name',
#    'of',
#    'the',
#    '``',
#    'Little',
#    'Rascals',
#    "''",
#    'dog',
#    '?'],),
#  (['city',
#    'What',
#    'city',
#    'boasts',
#    'Penn',
#    "'s",
#    'Landing',
#    ',',
#    'on',
#    'the',
#    'banks',
#    'of',
#    'the',
#    'Delaware',
#    'river',
#    '?'],),
#  (['cremat',
#    'What',
#    'Broadway',
#    'musical',
#    'was',
#    'inspired',
#    'by',
#    'Cervantes',
#    "'s",
#    'Don',
#    'Quixote',
#    '?'],),
#  (['desc',
#    'What',
#    'is',
#    'the',
#    'origin',
#    'of',
#    'the',
#    'word',
#    ',',
#    'JJ',
#    '.'],),
#  (['count',
#    'How',
#    'many',
#    'hostages',
#    'were',
#    'killed',
#    'in',
#    'the',
#    'Entebbe',
#    'raid',
#    '?'],),
#  (['manner', 'How', 'you', 'can', 'raise', 'your', 'IQ', '?'],),
#  (['exp',
#    'What',
#    'does',
#    'INRI',
#    'stand',
#    'for',
#    'when',
#    'used',
#    'on',
#    'Jesus',
#    "'",
#    'cross',
#    '?'],),
#  (['gr', 'Who', 'produces', 'Spumante', '?'],),
#  (['ind', 'Who', 'earns', 'their', 'money', 'the', 'hard', 'way', '?'],),
#  (['ind', 'Who', 'founded', 'the', 'People', "'s", 'Temple', 'Commune', '?'],),
#  (['ind',
#    'What',
#    'athlete',
#    'makes',
#    'the',
#    'most',
#    'money',
#    'from',
#    'sports',
#    'merchandise',
#    'sales',
#    '?'],),
#  (['count',
#    'How',
#    'many',
#    'bends',
#    'are',
#    'there',
#    'in',
#    'a',
#    'standard',
#    'paper',
#    'clip',
#    '?'],),
#  (['ind', 'Who', 'discovered', 'electricity', '?'],),
#  (['body',
#    'What',
#    'part',
#    'of',
#    'your',
#    'body',
#    'contains',
#    'the',
#    'corpus',
#    'callosum',
#    '?'],),
#  (['ind', 'Who', 'was', 'the', 'first', 'American', 'in', 'space', '?'],),
#  (['country',
#    'What',
#    'two',
#    'South',
#    'American',
#    'countries',
#    'do',
#    "n't",
#    'border',
#    'Brazil',
#    '?'],),
#  (['cremat',
#    'What',
#    'album',
#    'put',
#    'The',
#    'Beatles',
#    'on',
#    'the',
#    'cover',
#    'of',
#    'Time',
#    'in',
#    '####',
#    '?'],),
#  (['cremat',
#    'What',
#    'poem',
#    'contains',
#    'the',
#    'line',
#    ',',
#    '``',
#    'grow',
#    'old',
#    'with',
#    'me',
#    'the',
#    'best',
#    'is',
#    'yet',
#    'to',
#    'be',
#    "''",
#    '.'],),
#  (['def', 'What', 'is', 'a', 'dental', 'root', 'canal', '?'],),
#  (['event',
#    'What',
#    'war',
#    'did',
#    'the',
#    'Wanna-Go-Home',
#    'Riots',
#    'occur',
#    'after',
#    '?'],),
#  (['date', 'What', 'is', 'the', 'busiest', 'air', 'travel', 'season', '?'],),
#  (['body',
#    'What',
#    "'s",
#    'the',
#    'colored',
#    'part',
#    'of',
#    'the',
#    'eye',
#    'called',
#    '?'],),
#  (['def', 'What', 'are', 'hook', 'worms', '?'],),
#  (['other', 'Where', 'is', 'the', 'Rose', 'Bowl', 'played', '?'],),
#  (['gr',
#    'Which',
#    'Japanese',
#    'car',
#    'maker',
#    'had',
#    'its',
#    'biggest',
#    'percentage',
#    'of',
#    'sale',
#    'in',
#    'the',
#    'domestic',
#    'market',
#    '?'],),
#  (['ind', 'Who', 'is', 'the', 'mayor', 'of', 'Marbella', '?'],),
#  (['other',
#    'What',
#    'sun-blasted',
#    ',',
#    '##-mile',
#    'wide',
#    'valley',
#    'is',
#    'just',
#    'north',
#    'of',
#    'the',
#    'Mojave',
#    'desert',
#    '?'],),
#  (['date',
#    'In',
#    'what',
#    'year',
#    'did',
#    'Thatcher',
#    'become',
#    'prime',
#    'minister',
#    '?'],),
#  (['count',
#    'How',
#    'many',
#    'months',
#    'does',
#    'it',
#    'take',
#    'the',
#    'moon',
#    'to',
#    'revolve',
#    'around',
#    'the',
#    'Earth',
#    '?'],),
#  (['other', 'Where', 'are', 'the', '##', 'steps', '?'],),
#  (['date',
#    'In',
#    'what',
#    'year',
#    'was',
#    'De',
#    'Gaulle',
#    'elected',
#    'president',
#    'of',
#    'France',
#    '?'],),
#  (['ind',
#    'Who',
#    'sings',
#    'the',
#    'themes',
#    'for',
#    '``',
#    'Dawson',
#    "'s",
#    'Creek',
#    "''",
#    'and',
#    '``',
#    'Felicity',
#    "''",
#    '?'],),
#  (['ind', 'Who', 'directed', '``', 'Jaws', "''", '?'],),
#  (['cremat',
#    'On',
#    'what',
#    'T.V.',
#    'show',
#    'could',
#    'Tom',
#    'Terrific',
#    'be',
#    'found',
#    '?'],),
#  (['gr',
#    'What',
#    'Indian',
#    'tribe',
#    'is',
#    'F',
#    'Troop',
#    'perpetually',
#    'doing',
#    'battle',
#    'with',
#    '?'],),
#  (['desc', 'Where', 'did', 'Indian', 'Pudding', 'come', 'from', '?'],),
#  (['reason',
#    'Why',
#    'do',
#    'some',
#    'clothing',
#    'labels',
#    'say',
#    '``',
#    'Use',
#    'a',
#    'nonchlorine',
#    'bleach',
#    "''",
#    '?'],),
#  (['count',
#    'How',
#    'many',
#    'colonies',
#    'were',
#    'involved',
#    'in',
#    'the',
#    'American',
#    'Revolution',
#    '?'],),
#  (['city',
#    'What',
#    'is',
#    'the',
#    'name',
#    'of',
#    'the',
#    'city',
#    'that',
#    'Maurizio',
#    'Pellegrin',
#    'lives',
#    'in',
#    '?'],),
#  (['other',
#    'Where',
#    'can',
#    'I',
#    'find',
#    'pictorial',
#    'directions',
#    'on',
#    'how',
#    'to',
#    'build',
#    'a',
#    'very',
#    'simple',
#    'treehouse',
#    '?'],),
#  (['sport',
#    'What',
#    'game',
#    "'s",
#    'board',
#    'shows',
#    'the',
#    'territories',
#    'of',
#    'Irkutsk',
#    ',',
#    'Yakutsk',
#    'and',
#    'Kamchatka',
#    '?'],),
#  (['ind',
#    'What',
#    'is',
#    'the',
#    'name',
#    'of',
#    'the',
#    'managing',
#    'director',
#    'of',
#    'Apricot',
#    'Computer',
#    '?'],),
#  (['title',
#    'What',
#    'is',
#    'the',
#    'occupation',
#    'of',
#    'Nicholas',
#    'Cage',
#    '?'],),
#  (['reason', 'Why', 'do', 'horseshoes', 'bring', 'luck', '?'],),
#  (['def', 'What', 'is', 'the', '###', ',', 'K', ',', 'plan', '?'],),
#  (['reason', 'What', 'causes', 'pneumonia', '?'],),
#  (['date',
#    'What',
#    'are',
#    'the',
#    'three',
#    'winter',
#    'months',
#    'in',
#    'the',
#    'southern',
#    'hemisphere',
#    '?'],),
#  (['def', 'What', 'does', 'gringo', 'mean', '?'],),
#  (['country',
#    'What',
#    'country',
#    'contains',
#    'Africa',
#    "'s",
#    'northernmost',
#    'point',
#    '?'],),
#  (['dismed',
#    'What',
#    'therapy',
#    'attempts',
#    'to',
#    'elicit',
#    'the',
#    '``',
#    'primal',
#    'scream',
#    "''",
#    '?'],),
#  (['other', 'Where', 'is', 'the', 'Kalahari', 'desert', '?'],),
#  (['gr',
#    'Which',
#    'Ventura',
#    'County',
#    'police',
#    'department',
#    'seized',
#    'the',
#    'largest',
#    'cocaine',
#    'shipment',
#    'in',
#    'it',
#    "'s",
#    'history',
#    '?'],),
#  (['city', 'What', 'city', 'is', 'sometimes', 'called', 'Gotham', '?'],),
#  (['body',
#    'What',
#    'dangles',
#    'over',
#    'the',
#    'tongue',
#    'from',
#    'the',
#    'palate',
#    '?'],),
#  (['ind', 'Who', 'created', 'Dennis', 'the', 'Menace', '?'],),
#  (['ind',
#    'What',
#    'dummy',
#    'received',
#    'an',
#    'honorary',
#    'degree',
#    'from',
#    'Northwestern',
#    'University',
#    '?'],),
#  (['date',
#    'When',
#    'was',
#    'the',
#    'first',
#    'Wall',
#    'Street',
#    'Journal',
#    'published',
#    '?'],),
#  (['country',
#    'What',
#    'countries',
#    'have',
#    'the',
#    'largest',
#    'areas',
#    'of',
#    'forest',
#    '?'],),
#  (['manner',
#    'How',
#    'do',
#    'I',
#    'start',
#    'a',
#    'web',
#    'based',
#    'business',
#    '?'],),
#  (['ind', 'Name', 'Alvin', "'s", 'brothers'],),
#  (['def',
#    'What',
#    'is',
#    'Eagle',
#    "'s",
#    'syndrome',
#    'styloid',
#    'process',
#    '?'],),
#  (['manner', 'How', 'did', 'Jayne', 'Mansfield', 'die', '?'],),
#  (['date',
#    'When',
#    'did',
#    'the',
#    'royal',
#    'wedding',
#    'of',
#    'Prince',
#    'Andrew',
#    'and',
#    'Fergie',
#    'take',
#    'place',
#    '?'],),
#  (['ind', 'What', 'actor', 'said', 'in', 'A', 'Day', 'at', 'the', 'Races'],),
#  (['ind',
#    'What',
#    'explorer',
#    'was',
#    'nicknamed',
#    'Iberia',
#    "'s",
#    'Pilot',
#    '?'],),
#  (['date', 'CNN', 'began', 'broadcasting', 'in', 'what', 'year', '?'],),
#  (['termeq',
#    'What',
#    'is',
#    'a',
#    'ball',
#    'that',
#    'hits',
#    'the',
#    'foul',
#    'pole',
#    'called',
#    '?'],),
#  (['reason',
#    'What',
#    'makes',
#    'hamburgers',
#    'taste',
#    'like',
#    'steakburgers',
#    '?'],),
#  (['gr',
#    'Which',
#    'company',
#    'created',
#    'the',
#    'Internet',
#    'browser',
#    'Mosaic',
#    '?'],),
#  (['event',
#    'What',
#    'are',
#    'the',
#    'rites',
#    'accompanying',
#    'the',
#    'circumcision',
#    'of',
#    'a',
#    'newly',
#    'born-child',
#    'in',
#    'Judaism',
#    'called',
#    '?'],),
#  (['other',
#    'What',
#    'was',
#    'the',
#    'education',
#    'system',
#    'in',
#    'the',
#    '####',
#    "'s",
#    '?'],),
#  (['city',
#    'What',
#    'South',
#    'American',
#    'city',
#    'has',
#    'the',
#    'world',
#    "'s",
#    'highest',
#    'commercial',
#    'landing',
#    'field',
#    '?'],),
#  (['manner',
#    'How',
#    'can',
#    'I',
#    'find',
#    'out',
#    'which',
#    'cities',
#    'have',
#    'cable-modem',
#    'access',
#    '?'],),
#  (['reason', 'What', 'is', 'Betsy', 'Ross', 'famous', 'for', '?'],),
#  (['count', 'How', 'many', 'species', 'of', 'sharks', 'are', 'there', '?'],),
#  (['def', 'What', 'is', '``', 'snoogans', "''", '?'],),
#  (['count',
#    'How',
#    'many',
#    'people',
#    'are',
#    'there',
#    'in',
#    'the',
#    'world',
#    '?'],),
#  (['plant',
#    'What',
#    'shrubs',
#    'can',
#    'be',
#    'planted',
#    'that',
#    'will',
#    'be',
#    'safe',
#    'from',
#    'deer',
#    '?'],),
#  (['gr',
#    'What',
#    'organization',
#    "'s",
#    'offices',
#    'were',
#    'broken',
#    'into',
#    'at',
#    'Watergate',
#    'in',
#    '####',
#    '?'],),
#  (['desc',
#    'What',
#    'is',
#    'the',
#    'design',
#    'of',
#    'the',
#    'ship',
#    'Titanic',
#    '?'],),
#  (['exp', 'What', 'does', 'S.O.S.', 'stand', 'for', '?'],),
#  (['techmeth',
#    'Name',
#    'a',
#    'technique',
#    'widely',
#    'used',
#    'to',
#    'detect',
#    'birth',
#    'defects',
#    '?'],),
#  (['desc',
#    'What',
#    'is',
#    'the',
#    'daily',
#    'requirement',
#    'of',
#    'folic',
#    'acid',
#    'for',
#    'an',
#    'expectant',
#    'mother',
#    '?'],),
#  (['def', 'What', 'is', 'the', '``', '#-minute', 'cigarette', "''", '?'],),
#  (['other', 'What', 'four', 'forms', 'does', 'gold', 'occur', 'in', '?'],),
#  (['volsize',
#    'What',
#    'is',
#    'the',
#    'acreage',
#    'of',
#    'the',
#    'Chappellet',
#    'vineyard',
#    '?'],),
#  (['manner',
#    'How',
#    'do',
#    'you',
#    'correctly',
#    'say',
#    'the',
#    'word',
#    '`',
#    'qigong',
#    "'",
#    '?'],),
#  (['date', 'When', 'did', 'beethoven', 'die', '?'],),
#  (['money',
#    'How',
#    'much',
#    'does',
#    'a',
#    'new',
#    'railroad',
#    'coal',
#    'car',
#    'cost',
#    '?'],),
#  (['country',
#    'What',
#    'two',
#    'European',
#    'countries',
#    'entered',
#    'the',
#    'War',
#    'of',
#    'American',
#    'Independence',
#    'against',
#    'the',
#    'British',
#    '?'],),
#  (['def', 'What', 'is', 'the', 'filmmakers', 'collabrative', '?'],),
#  (['ind',
#    'What',
#    'Russian',
#    'composer',
#    "'s",
#    'Prelude',
#    'in',
#    'C',
#    'Sharp',
#    'Minor',
#    'brought',
#    'him',
#    'fame',
#    'and',
#    'fortune',
#    '?'],),
#  (['reason', 'What', 'caused', 'Harry', 'Houdini', "'s", 'death', '?'],),
#  (['ind',
#    'Who',
#    'was',
#    'the',
#    'mother',
#    'of',
#    'the',
#    'man',
#    'who',
#    'would',
#    'not',
#    'be',
#    'king',
#    ',',
#    'the',
#    'duke',
#    'of',
#    'Windsor',
#    '?'],),
#  (['count',
#    'How',
#    'many',
#    'revolutions',
#    'does',
#    'a',
#    'standard',
#    'LP',
#    'make',
#    'in',
#    'three',
#    'minutes',
#    '?'],),
#  (['mount',
#    'What',
#    'is',
#    'the',
#    'name',
#    'of',
#    'the',
#    'tallest',
#    'mountain',
#    'in',
#    'the',
#    'world',
#    '?'],),
#  (['other',
#    'Where',
#    'can',
#    'I',
#    'find',
#    'a',
#    'review',
#    'of',
#    'Nightmare',
#    'on',
#    'Elm',
#    'Street',
#    'in',
#    'a',
#    'film',
#    'journal',
#    '?'],),
#  (['techmeth',
#    'What',
#    "'s",
#    'the',
#    'slowest',
#    'Olympic',
#    'swimming',
#    'stroke',
#    '?'],),
#  (['ind',
#    'What',
#    'was',
#    'the',
#    'name',
#    'of',
#    'the',
#    'first',
#    'Russian',
#    'astronaut',
#    'to',
#    'do',
#    'a',
#    'spacewalk',
#    '?'],),
#  (['dismed',
#    'What',
#    'disease',
#    'is',
#    'transmitted',
#    'by',
#    'the',
#    'Anopheles',
#    'mosquito',
#    '?'],),
#  (['food',
#    'What',
#    'rum',
#    'is',
#    'so',
#    '``',
#    'mixable',
#    "''",
#    'it',
#    'is',
#    'a',
#    'one-brand',
#    'bar',
#    '?'],),
#  (['count',
#    'How',
#    'many',
#    'South',
#    'American',
#    'countries',
#    'have',
#    'the',
#    'letter',
#    'Z',
#    'in',
#    'their',
#    'names',
#    '?'],),
#  (['def', 'What', 'is', 'the', 'contents', 'of', 'proposition', '##', '?'],),
#  (['other', 'Where', 'was', 'George', 'Washington', 'born', '?'],),
#  (['count',
#    'How',
#    'many',
#    'people',
#    'on',
#    'the',
#    'ground',
#    'were',
#    'killed',
#    'from',
#    'the',
#    'bombing',
#    'of',
#    'Pan',
#    'Am',
#    'Flight',
#    '###',
#    'over',
#    'Lockerbie',
#    ',',
#    'Scotland',
#    ',',
#    'December',
#    '##',
#    ',',
#    'CD',
#    '.'],),
#  (['ind', 'Who', 'wrote', 'NN', 'DT', 'NNP', 'NNP', "''", '?'],),
#  (['def', 'What', 'is', 'paracetamol', '?'],),
#  (['desc',
#    'What',
#    'are',
#    'the',
#    'powers',
#    'and',
#    'weaknesses',
#    'of',
#    'Green',
#    'Lantern',
#    "'s",
#    'ring',
#    '?'],),
#  (['animal',
#    'Which',
#    'mosquito',
#    "'s",
#    'bite',
#    'draws',
#    'blood',
#    ',',
#    'DT',
#    'NN',
#    'CC',
#    'DT',
#    'NN',
#    '.'],),
#  (['date',
#    'When',
#    'was',
#    'the',
#    'first',
#    'steel',
#    'mill',
#    'in',
#    'the',
#    'United',
#    'States',
#    'built',
#    '?'],),
#  (['ind',
#    'What',
#    'diminutive',
#    'American',
#    'female',
#    'gymnast',
#    'stole',
#    'the',
#    'show',
#    'at',
#    'the',
#    '####',
#    'Olympics',
#    '?'],),
#  (['desc', 'What', 'is', 'the', 'origin', 'of', 'the', 'name', 'Katie', '?'],),
#  (['gr',
#    'What',
#    'schools',
#    'in',
#    'the',
#    'Washington',
#    ',',
#    'DC',
#    'NN',
#    'NN',
#    'VBP',
#    'NN',
#    'NN',
#    'NN',
#    'NN',
#    '.'],),
#  (['date', 'When', 'did', 'the', 'Berlin', 'Wall', 'go', 'up', '?'],),
#  (['desc', 'Who', 'is', 'Terrence', 'Malick', '?'],),
#  (['instru',
#    'What',
#    'instrument',
#    'is',
#    'Ray',
#    'Charles',
#    'best',
#    'known',
#    'for',
#    'playing',
#    '?'],),
#  (['def',
#    'What',
#    "'s",
#    'the',
#    'meaning',
#    'of',
#    'the',
#    'Latin',
#    'battle',
#    'cry'],),
#  (['other',
#    'What',
#    'is',
#    'the',
#    'mascot',
#    'for',
#    'Notre',
#    'Dame',
#    'University',
#    '?'],),
#  (['other',
#    'What',
#    'Las',
#    'Vegas',
#    'hotel',
#    'burned',
#    'in',
#    'November',
#    ',',
#    '####',
#    ',',
#    'with',
#    'the',
#    'loss',
#    'of',
#    '##',
#    'lives',
#    '?'],),
#  (['date',
#    'When',
#    'did',
#    'Mount',
#    'St.',
#    'Helen',
#    'last',
#    'have',
#    'a',
#    'significant',
#    'eruption',
#    '?'],),
#  (['exp', 'CNN', 'is', 'the', 'abbreviation', 'for', 'what', '?'],),
#  (['date', 'When', 'did', 'World', 'War', 'I', 'start', '?'],),
#  (['count', 'How', 'many', 'feet', 'are', 'there', 'in', 'a', 'fathom', '?'],),
#  (['def', 'What', 'is', 'a', 'Canada', 'two-penny', 'black', '?'],),
#  (['city', 'What', 'European', 'city', 'do', 'Nicois', 'live', 'in', '?'],),
#  (['manner',
#    'How',
#    'can',
#    'I',
#    'find',
#    'out',
#    'what',
#    'year',
#    'a',
#    'Beanie',
#    'Baby',
#    'was',
#    'introduced',
#    '?'],),
#  (['def',
#    'What',
#    'is',
#    'the',
#    'classic',
#    'definition',
#    'of',
#    'tragic',
#    'hero',
#    '?'],),
#  (['other',
#    'To',
#    'what',
#    'does',
#    'Microsoft',
#    "'s",
#    'Windows',
#    '#',
#    'owe',
#    'its',
#    'success',
#    '?'],),
#  (['ind', 'Who', 'was', 'President', 'of', 'Afghanistan', 'in', '####', '?'],),
#  (['techmeth',
#    'What',
#    'are',
#    'other',
#    'ways',
#    'of',
#    'getting',
#    'stretch',
#    'marks',
#    'besides',
#    'pregnancy',
#    ',',
#    'weight',
#    'loss',
#    ',',
#    'and',
#    'weight',
#    'lifting',
#    '?'],),
#  (['food', 'What', 'did', 'brontosauruses', 'eat', '?'],),
#  (['color',
#    'What',
#    'color',
#    'bottles',
#    'do',
#    'good',
#    'Rhine',
#    'wines',
#    'come',
#    'in',
#    '?'],),
#  (['ind',
#    'Who',
#    'was',
#    'the',
#    'lead',
#    'actress',
#    'in',
#    'the',
#    'movie',
#    '`',
#    'Sleepless',
#    'in',
#    'Seattle',
#    "'",
#    '?'],),
#  (['ind',
#    'Who',
#    'was',
#    'the',
#    '##th',
#    'President',
#    'of',
#    'the',
#    'United',
#    'States',
#    '?'],),
#  (['ind',
#    'Who',
#    'are',
#    'the',
#    'two',
#    'sons',
#    'of',
#    'Ozzie',
#    'and',
#    'Harriet',
#    'Nelson',
#    '?'],),
#  (['def', 'What', 'is', 'molybdenum', '?'],),
#  (['date', 'When', 'is', 'Boxing', 'Day', '?'],),
#  (['other',
#    'What',
#    'is',
#    'the',
#    'lowest',
#    'level',
#    'of',
#    'the',
#    'American',
#    'judiciary',
#    '?'],),
#  (['date',
#    'When',
#    'was',
#    'the',
#    'battle',
#    'of',
#    'the',
#    'Somme',
#    'fought',
#    '?'],),
#  (['count', 'How', 'many', 'people', 'did', 'Randy', 'Craft', 'kill', '?'],),
#  (['animal', 'What', "'s", 'the', 'official', 'animal', 'of', 'Canada', '?'],),
#  (['date', 'When', 'did', 'Spielberg', 'direct', '``', 'Jaws', "''", '?'],),
#  (['volsize',
#    'What',
#    'is',
#    'the',
#    'size',
#    'of',
#    'the',
#    'largest',
#    'akita',
#    '?'],),
#  (['animal', 'What', 'animal', 'has', 'the', 'biggest', 'eyes', '?'],),
#  (['city', 'What', 'is', 'California', "'s", 'capital', '?'],),
#  (['ind',
#    'Who',
#    'was',
#    'the',
#    'author',
#    'of',
#    'the',
#    'book',
#    'about',
#    'computer',
#    'hackers',
#    'called',
#    '``',
#    'The',
#    'Cuckoo',
#    "'s",
#    'Egg'],),
#  (['ind',
#    'Who',
#    'was',
#    'the',
#    'founding',
#    'member',
#    'of',
#    'the',
#    'Pink',
#    'Floyd',
#    'band',
#    '?'],),
#  (['country',
#    'What',
#    'European',
#    'country',
#    'is',
#    'home',
#    'to',
#    'the',
#    'beer-producing',
#    'city',
#    'of',
#    'Budweis',
#    '?'],),
#  (['manner',
#    'How',
#    'do',
#    'I',
#    'find',
#    'the',
#    'balance',
#    'of',
#    'my',
#    'social',
#    'security',
#    'account',
#    '?'],),
#  (['desc',
#    'What',
#    'is',
#    'the',
#    'history',
#    'of',
#    'Valentine',
#    "'s",
#    'Day',
#    'cards',
#    '?'],),
#  (['other', 'Where', 'was', 'Christopher', 'Columbus', 'born', '?'],),
#  (['termeq', 'What', 'do', 'Italians', 'call', 'Florence', '?'],),
#  (['manner',
#    'How',
#    'do',
#    'you',
#    'get',
#    'to',
#    'the',
#    'top',
#    'of',
#    'the',
#    'Eiffel',
#    'Tower',
#    '?'],),
#  (['exp', 'What', 'does', '`', 'PSI', "'", 'stand', 'for', '?'],),
#  (['other',
#    'What',
#    'sea',
#    'did',
#    'the',
#    'Romans',
#    'call',
#    'mare',
#    'nostrum',
#    '?'],),
#  (['termeq',
#    'What',
#    "'s",
#    'the',
#    'term',
#    'for',
#    'a',
#    'bet',
#    'before',
#    'cards',
#    'are',
#    'dealt',
#    '?'],),
#  (['animal',
#    'Which',
#    'came',
#    'first',
#    ',',
#    'according',
#    'to',
#    'Genesis',
#    '#'],),
#  (['city', 'What', 'city', 'did', 'the', 'Flintstones', 'live', 'in', '?'],),
#  (['termeq', 'What', 'is', 'Latin', 'for', 'incompetent', '?'],),
#  (['dismed',
#    'What',
#    'chemicals',
#    'are',
#    'used',
#    'in',
#    'lethal',
#    'injection',
#    '?'],),
#  (['gr',
#    'What',
#    'toy',
#    'company',
#    'is',
#    'the',
#    'world',
#    "'s",
#    'No.#',
#    'maker',
#    'of',
#    'female',
#    'apparel',
#    '?'],),
#  (['sport',
#    'What',
#    'board',
#    'game',
#    'does',
#    'a',
#    '``',
#    'wood-pusher',
#    "''",
#    'play',
#    'poorly',
#    '?'],),
#  (['ind',
#    'Which',
#    'Doonesbury',
#    'character',
#    'was',
#    'likely',
#    'to',
#    'turn',
#    'into',
#    'a',
#    'werewolf',
#    '?'],),
#  (['abb', 'What', 'is', 'the', 'abbreviation', 'for', 'micro', '?'],),
#  (['other',
#    'What',
#    'are',
#    'the',
#    '#',
#    'articles',
#    'of',
#    'the',
#    'constitution',
#    '?'],),
#  (['gr', 'Who', 'has', 'won', 'the', 'most', 'Super', 'Bowls', '?'],),
#  (['exp', 'What', 'does', 'NASDAQ', 'stand', 'for', '?'],),
#  (['exp', 'What', 'is', 'BPH', '?'],),
#  (['other',
#    'What',
#    'is',
#    'the',
#    'fastest',
#    'commercial',
#    'automobile',
#    'that',
#    'can',
#    'be',
#    'bought',
#    'in',
#    'the',
#    'US',
#    '?'],),
#  (['other',
#    'What',
#    'stadium',
#    'do',
#    'the',
#    'Miami',
#    'Dolphins',
#    'play',
#    'their',
#    'home',
#    'games',
#    'in',
#    '?'],),
#  (['ind',
#    'Who',
#    'has',
#    'the',
#    'only',
#    'speaking',
#    'role',
#    'in',
#    '``',
#    'Silent',
#    'Movie',
#    "''",
#    '?'],),
#  (['reason', 'Why', 'is', 'poop', 'sometimes', 'different', 'colors', '?'],),
#  (['other', 'What', 'was', 'Einstein', "'s", 'IQ', '?'],),
#  (['date',
#    'What',
#    'day',
#    'was',
#    'Pearl',
#    'Harbor',
#    'attacked',
#    'in',
#    '####',
#    '?'],),
#  (['ind',
#    'What',
#    'girl',
#    "'s",
#    'name',
#    'is',
#    '``',
#    'Teddy',
#    "''",
#    'an',
#    'affectionate',
#    'form',
#    'of',
#    '?'],),
#  (['state',
#    'What',
#    'state',
#    'is',
#    'John',
#    'F.',
#    'Kennedy',
#    'buried',
#    'in',
#    '?'],),
#  (['techmeth',
#    'What',
#    'is',
#    'the',
#    'best',
#    'way',
#    'to',
#    'remove',
#    'wallpaper',
#    '?'],),
#  (['state',
#    'What',
#    'U.S.',
#    'state',
#    'has',
#    'an',
#    'element',
#    'named',
#    'for',
#    'it',
#    '?'],),
#  (['gr',
#    'What',
#    'company',
#    'tabulates',
#    'the',
#    'ballots',
#    'in',
#    'voting',
#    'for',
#    'the',
#    'Academy',
#    'Awards',
#    '?'],),
#  (['manner',
#    'How',
#    'did',
#    'the',
#    'tradition',
#    'of',
#    'best',
#    'man',
#    'start',
#    '?'],),
#  (['count',
#    'How',
#    'many',
#    'years',
#    'ago',
#    'did',
#    'the',
#    'ship',
#    'Titanic',
#    'sink',
#    '?'],),
#  (['other',
#    'What',
#    'is',
#    'the',
#    'deepest',
#    'area',
#    'of',
#    'the',
#    'Arctic',
#    'Ocean',
#    '?'],),
#  (['color', 'What', 'are', 'Halloween', "'s", 'colors', '?'],),
#  (['manner', 'How', 'is', 'silk', 'screening', 'done', '?'],),
#  (['other',
#    'What',
#    'is',
#    'the',
#    'latitude',
#    'and',
#    'longitude',
#    'of',
#    'El',
#    'Paso',
#    ',',
#    'Texas',
#    '?'],),
#  (['ind', 'Who', 'made', 'a', 'boat', 'out', 'of', 'gopher', 'wood', '?'],),
#  (['other',
#    'Where',
#    'can',
#    'I',
#    'find',
#    'a',
#    '``',
#    'Fifth',
#    'Element',
#    "''",
#    'screensaver',
#    '?'],),
#  (['ind',
#    'Which',
#    'Bloom',
#    'County',
#    'resident',
#    'wreaks',
#    'havoc',
#    'with',
#    'a',
#    'computer',
#    '?'],),
#  (['manner',
#    'How',
#    'do',
#    'you',
#    'match',
#    'a',
#    'name',
#    'to',
#    'a',
#    'social',
#    'security',
#    'number',
#    '?'],),
#  (['manner', 'How', 'does', 'a', 'rainbow', 'form', '?'],),
#  (['other',
#    'What',
#    'is',
#    'the',
#    'normal',
#    'resting',
#    'heart',
#    'rate',
#    'of',
#    'a',
#    'healthy',
#    'adult',
#    '?'],),
#  (['other', 'What', 'is', 'the', 'population', 'of', 'Ohio', '?'],),
#  (['count',
#    'How',
#    'many',
#    'calories',
#    'are',
#    'there',
#    'in',
#    'a',
#    'Big',
#    'Mac',
#    '?'],),
#  (['def', 'Hazmat', 'stands', 'for', 'what', '?'],),
#  (['animal',
#    'What',
#    'creature',
#    'scares',
#    'people',
#    'in',
#    'the',
#    'film',
#    '``',
#    'Jaws',
#    "''",
#    '?'],),
#  (['ind',
#    'What',
#    'part',
#    'did',
#    'John',
#    'Peter',
#    'Zenger',
#    'play',
#    'in',
#    'the',
#    'deveopment',
#    'of',
#    'the',
#    'newspaper',
#    'in',
#    'America',
#    '?'],),
#  (['ind', 'Who', 'followed', 'Caesar', '?'],),
#  (['substance', 'What', 'are', 'the', 'four', 'elements', '?'],),
#  (['ind',
#    'Who',
#    'was',
#    'the',
#    'first',
#    'woman',
#    'golfer',
#    'to',
#    'earn',
#    'a',
#    'million',
#    '?'],),
#  (['other',
#    'What',
#    "'s",
#    'the',
#    'tallest',
#    'piece',
#    'on',
#    'a',
#    'chessboard',
#    '?'],),
#  (['other', 'What', 'is', 'Answers.com', "'s", 'address', '?'],),
#  (['other',
#    'Where',
#    'can',
#    'I',
#    'buy',
#    'movies',
#    'on',
#    'videotape',
#    'online',
#    '?'],),
#  (['ind', 'Who', 'does', 'the', 'advertizing', 'for', 'Frito-Lay', '?'],),
#  (['gr',
#    'Who',
#    'is',
#    'the',
#    'leading',
#    'competitor',
#    'of',
#    'Trans',
#    'Union',
#    'Company',
#    '?'],),
#  (['product',
#    'What',
#    'product',
#    'did',
#    'Robert',
#    'Conrad',
#    'dare',
#    'people',
#    'to',
#    'knock',
#    'off',
#    'his',
#    'shoulder',
#    '?'],),
#  (['ind', 'Who', 'invented', 'the', 'radio', '?'],),
#  (['count',
#    'What',
#    "'s",
#    'the',
#    'American',
#    'dollar',
#    'equivalent',
#    'for',
#    '#',
#    'pounds',
#    'in',
#    'the',
#    'U.K.',
#    '?'],),
#  (['techmeth',
#    'What',
#    'are',
#    'the',
#    'different',
#    'approaches',
#    'of',
#    'systems',
#    'analysis',
#    '?'],),
#  (['manner', 'How', 'do', 'doctors', 'diagnose', 'bone', 'cancer', '?'],),
#  (['ind',
#    'Who',
#    'is',
#    'the',
#    'man',
#    'behind',
#    'the',
#    'pig-the',
#    'man',
#    'who',
#    'pulls',
#    'the',
#    'strings',
#    'and',
#    'speaks',
#    'for',
#    'Miss',
#    'Piggy',
#    '?'],),
#  (['speed',
#    'What',
#    'is',
#    'the',
#    'speed',
#    'of',
#    'the',
#    'Mississippi',
#    'River',
#    '?'],),
#  (['other',
#    'What',
#    'are',
#    'the',
#    'developmental',
#    'stages',
#    'of',
#    'a',
#    'swimmer',
#    '?'],),
#  (['ind', 'What', 'actor', 'first', 'portrayed', 'James', 'Bond', '?'],),
#  (['other',
#    'What',
#    'ocean',
#    'is',
#    'the',
#    'largest',
#    'in',
#    'the',
#    'world',
#    '?'],),
#  (['ind',
#    'Who',
#    'was',
#    'the',
#    'first',
#    'American',
#    'poet',
#    'to',
#    'win',
#    'the',
#    'Nobel',
#    'Prize',
#    'for',
#    'literature',
#    ',',
#    'in',
#    '####',
#    '?'],),
#  (['date',
#    'What',
#    'year',
#    'did',
#    'Jack',
#    'Nicklaus',
#    'join',
#    'the',
#    'Professional',
#    'Golfers',
#    'Association',
#    'tour',
#    '?'],),
#  (['count', 'How', 'many', 'sonnets', 'did', 'Shakespeare', 'write', '?'],),
#  (['reason',
#    'What',
#    'causes',
#    'the',
#    'redness',
#    'in',
#    'your',
#    'cheeks',
#    'when',
#    'you',
#    'blush',
#    '?'],),
#  (['ind', 'Who', 'won', 'the', 'Nobel', 'Peace', 'Prize', 'in', '####', '?'],),
#  (['gr', 'Who', 'are', 'the', 'Challengers', 'of', 'the', 'Unknown', '?'],),
#  (['def', 'Define', 'the', 'Pheonix', 'Club', '?'],),
#  (['city',
#    'Which',
#    'city',
#    'did',
#    'Christian',
#    'Crusaders',
#    'fight',
#    'to',
#    'recapture',
#    'from',
#    'the',
#    'Muslims',
#    '?'],),
#  (['def',
#    'What',
#    'does',
#    'it',
#    'mean',
#    '``',
#    'Rupee',
#    'Depreciates',
#    "''",
#    '?'],),
#  (['other',
#    'What',
#    'gaming',
#    'devices',
#    'were',
#    'dubbed',
#    '``',
#    'Mississippi',
#    'marbles',
#    "''",
#    'and',
#    '``',
#    'Memphis',
#    'dominoes',
#    "''",
#    '?'],),
#  (['ind',
#    'Who',
#    'was',
#    'the',
#    'first',
#    'coach',
#    'of',
#    'the',
#    'Cleveland',
#    'Browns',
#    '?'],),
#  (['manner', 'How', 'successful', 'is', 'arometherapy', '?'],),
#  (['event',
#    'What',
#    'Jewish',
#    'holiday',
#    'saw',
#    'the',
#    'start',
#    'of',
#    'the',
#    '####',
#    'Mideast',
#    'War',
#    '?'],),
#  (['manner', 'How', 'does', 'a', 'copier', 'work', '?'],),
#  (['speed',
#    'What',
#    'is',
#    'the',
#    'speed',
#    'of',
#    'the',
#    'Mississippi',
#    'River',
#    '?'],),
#  (['ind', 'Who', 'said', 'of', 'Super', 'Bowl', 'III', 'in', '####'],),
#  (['animal',
#    'What',
#    'is',
#    'Dudley',
#    'Do-Right',
#    "'s",
#    'horse',
#    "'s",
#    'name',
#    '?'],),
#  (['ind', 'Who', 'declared'],),
#  (['other', 'Where', 'does', 'chocolate', 'come', 'from', '?'],),
#  (['cremat',
#    'What',
#    'TV',
#    'game',
#    'show',
#    'once',
#    'saw',
#    'a',
#    'contestant',
#    'admit',
#    'to',
#    'picking',
#    'his',
#    'toes',
#    'in',
#    'the',
#    'shower',
#    '?'],),
#  (['ind', 'What', 'Soviet', 'leader', 'owned', 'a', 'Rolls-Royce', '?'],),
#  (['other',
#    'Where',
#    'can',
#    'I',
#    'find',
#    'a',
#    'case',
#    'on',
#    'Individuals',
#    'with',
#    'Disabilities',
#    'Education',
#    'Act',
#    'of',
#    '####',
#    '?'],),
#  (['event',
#    'What',
#    'war',
#    'did',
#    'Florence',
#    'Nightingale',
#    'tend',
#    'the',
#    'troops',
#    'in',
#    '?'],),
#  (['ind', 'Who', 'wrote', 'the', 'song', ',', '``', 'Stardust', "''", '?'],),
#  (['count', 'How', 'many', 'Beatles', "'", 'records', 'went', '##', '?'],),
#  (['ind',
#    'Who',
#    'is',
#    'the',
#    'only',
#    'prime',
#    'minister',
#    'of',
#    'Canada',
#    'to',
#    'serve',
#    '##',
#    'years',
#    'but',
#    'not',
#    'necessarily',
#    'consecutively',
#    '?'],),
#  (['abb',
#    'What',
#    'is',
#    'the',
#    'abbreviation',
#    'of',
#    'the',
#    'company',
#    'name',
#    '`',
#    'General',
#    'Motors',
#    "'",
#    '?'],),
#  (['mount',
#    'What',
#    'mountains',
#    'lie',
#    'between',
#    'the',
#    'Arkansas',
#    'and',
#    'Missouri',
#    'rivers',
#    '?'],),
#  (['ind',
#    'Who',
#    'received',
#    'the',
#    'Will',
#    'Rogers',
#    'Award',
#    'in',
#    '####',
#    '?'],),
#  (['reason', 'What', 'is', 'the', 'function', 'of', 'RAM', '?'],),
#  (['other',
#    'What',
#    "'s",
#    'the',
#    'closest',
#    'G#',
#    'Spectrum',
#    'Yellow',
#    'Dwarf',
#    'to',
#    'Earth',
#    '?'],),
#  (['count',
#    'How',
#    'many',
#    'equal',
#    'angles',
#    'are',
#    'there',
#    'in',
#    'an',
#    'isosceles',
#    'triangle',
#    '?'],),
#  (['dismed',
#    'What',
#    'is',
#    'the',
#    'fear',
#    'of',
#    'cockroaches',
#    'called',
#    '?'],),
#  (['cremat',
#    'What',
#    'CBS',
#    'soap',
#    'opera',
#    'was',
#    'interrupted',
#    'by',
#    'the',
#    'bulletin',
#    'of',
#    'John',
#    'F.',
#    'Kennedy',
#    "'s",
#    'assassination',
#    '?'],),
#  (['desc',
#    'What',
#    'is',
#    'the',
#    'use',
#    'of',
#    'a',
#    '##-hour',
#    'clock',
#    'instead',
#    'of',
#    'a',
#    '##-hour',
#    'clock',
#    '?'],),
#  (['ind',
#    'What',
#    'was',
#    'the',
#    'name',
#    'of',
#    'the',
#    'lawyer',
#    'who',
#    'represented',
#    'Randy',
#    'Craft',
#    '?'],),
#  (['ind',
#    'What',
#    'United',
#    'States',
#    'President',
#    'had',
#    'dreamed',
#    'that',
#    'he',
#    'was',
#    'assassinated',
#    '?'],),
#  (['cremat',
#    'What',
#    'film',
#    'did',
#    'Lee',
#    'Marvin',
#    'win',
#    'the',
#    '####',
#    'best',
#    'actor',
#    'Oscar',
#    'for',
#    '?'],),
#  (['other', 'Where', 'is', 'Basque', 'country', 'located', '?'],),
#  (['product',
#    'What',
#    'product',
#    'does',
#    '``',
#    'Mrs.',
#    'Olsen',
#    "''",
#    'promote',
#    '?'],),
#  (['date',
#    'What',
#    'time',
#    'of',
#    'day',
#    'did',
#    'Emperor',
#    'Hirohito',
#    'die',
#    '?'],),
#  (['def', 'What', 'is', 'dry', 'ice', '?'],),
#  (['other',
#    'What',
#    "'s",
#    'the',
#    'most',
#    'powerful',
#    'card',
#    'in',
#    'Euchre',
#    '?'],),
#  (['def',
#    'What',
#    'does',
#    '``',
#    'intractable',
#    'plantar',
#    'keratoma',
#    "''",
#    'mean',
#    '?'],),
#  (['count',
#    'How',
#    'many',
#    'years',
#    'did',
#    'it',
#    'take',
#    'James',
#    'Joyce',
#    'to',
#    'write',
#    'Ulysses',
#    '?'],),
#  (['food',
#    'What',
#    'crop',
#    'failure',
#    'caused',
#    'the',
#    'Irish',
#    'Famine',
#    '?'],),
#  (['city',
#    'What',
#    'South',
#    'Korean',
#    'city',
#    'is',
#    'served',
#    'by',
#    'Kimpo',
#    'International',
#    'Airport',
#    '?'],),
#  (['count',
#    'How',
#    'many',
#    'types',
#    'of',
#    'dogs',
#    "'",
#    'tails',
#    'are',
#    'there',
#    '-',
#    'three'],),
#  (['cremat',
#    'What',
#    'is',
#    'the',
#    'longest-running',
#    'television',
#    'series',
#    '?'],),
#  (['animal', 'What', 'predators', 'exist', 'on', 'Antarctica', '?'],),
#  (['desc',
#    'What',
#    'is',
#    'the',
#    'difference',
#    'between',
#    'a',
#    'generator',
#    'and',
#    'an',
#    'alternator',
#    '?'],),
#  (['manner', 'How', 'is', 'energy', 'created', '?'],),
#  (['food',
#    'What',
#    'beer',
#    'advertised',
#    'that',
#    'it',
#    'had',
#    '``',
#    'three',
#    'rings',
#    "''",
#    '?'],),
#  (['other',
#    'What',
#    'is',
#    'the',
#    'quantity',
#    'of',
#    'American',
#    'soldiers',
#    'still',
#    'unaccounted',
#    'for',
#    'from',
#    'the',
#    'Vietnam',
#    'war',
#    '?'],),
#  (['techmeth',
#    'What',
#    'golfing',
#    'accessory',
#    'was',
#    'patented',
#    'by',
#    'George',
#    'Grant',
#    'on',
#    'December',
#    '##'],),
#  (['other',
#    'What',
#    'are',
#    'the',
#    'different',
#    'types',
#    'of',
#    'plastic',
#    '?'],),
#  (['manner',
#    'How',
#    'is',
#    'it',
#    'correct',
#    'to',
#    'say',
#    '`',
#    'qigong',
#    "'",
#    '?'],),
#  (['mount',
#    'What',
#    'was',
#    'the',
#    'highest',
#    'mountain',
#    'on',
#    'earth',
#    'before',
#    'Mount',
#    'Everest',
#    'was',
#    'discovered',
#    '?'],),
#  (['other',
#    'Where',
#    'was',
#    'the',
#    'Ligurian',
#    'Republic',
#    ',',
#    '####-###',
#    ',',
#    '?'],),
#  (['country',
#    'What',
#    'country',
#    "'s",
#    'people',
#    'are',
#    'the',
#    'top',
#    'television',
#    'watchers',
#    '?'],),
#  (['date',
#    'When',
#    'was',
#    'the',
#    'women',
#    "'s",
#    'suffrage',
#    'amendment',
#    'ratified',
#    '?'],),
#  (['gr', 'What', 'Polynesian', 'people', 'inhabit', 'New', 'Zealand', '?'],),
#  (['cremat',
#    'What',
#    'movie',
#    'tour',
#    'of',
#    'the',
#    'Roman',
#    'empire',
#    'features',
#    'the',
#    'admonition'],),
#  (['city',
#    'What',
#    'Nevada',
#    'center',
#    'has',
#    'been',
#    'dubbed',
#    'The',
#    'Biggest',
#    'Little',
#    'City',
#    'in',
#    'the',
#    'World',
#    '?'],),
#  (['ind',
#    'What',
#    'President',
#    'lived',
#    'at',
#    '###',
#    'North',
#    'Delaware',
#    'Street',
#    ',',
#    'Independence',
#    ',',
#    'Missouri',
#    '?'],),
#  (['reason',
#    'Give',
#    'a',
#    'reason',
#    'for',
#    'American',
#    'Indians',
# ...
#    'whale',
#    'died',
#    'at',
#    'Sea',
#    'World',
#    'of',
#    'a',
#    'fungal',
#    'infection',
#    '?'],),
#  (['country', 'What', 'are', 'the', 'Benelux', 'countries', '?'],),
#  (['other', 'Where', "'s", 'the', 'Petrified', 'Forest', '?'],),
#  (['lang',
#    'What',
#    'is',
#    'a',
#    'language',
#    'spoken',
#    'by',
#    'the',
#    'Sioux',
#    '?'],),
#  (['other', 'Where', 'is', 'Tornado', 'Alley', '?'],),
#  (['ind',
#    'Who',
#    'was',
#    'the',
#    'author',
#    'of',
#    '``',
#    'John',
#    'Brown',
#    "'s",
#    'Body',
#    "''",
#    '?'],),
#  (['ind', 'What', 'American', 'poet', 'wrote'],),
#  (['state',
#    'What',
#    'state',
#    'in',
#    'the',
#    'U.S.',
#    'has',
#    'the',
#    'most',
#    'blacks',
#    '?'],),
#  (['reason',
#    'Why',
#    'are',
#    'electric',
#    'cars',
#    'less',
#    'efficient',
#    'in',
#    'the',
#    'northeast',
#    'than',
#    'in',
#    'California',
#    '?'],),
#  (['title',
#    'What',
#    'was',
#    'the',
#    'occupation',
#    'of',
#    'Mandy',
#    'Rice-Davies',
#    '?'],),
#  (['city',
#    'What',
#    'is',
#    'the',
#    'city',
#    'in',
#    'which',
#    'Maurizio',
#    'Pellegrin',
#    'lives',
#    'called',
#    '?'],),
#  (['ind', 'Who', 'painted', 'the', 'Sistine', 'Chapel', '?'],),
#  (['ind',
#    'Name',
#    'the',
#    'various',
#    'costumed',
#    'personas',
#    'of',
#    'Dr.',
#    'Henry',
#    'Pym',
#    '.'],),
#  (['animal',
#    'What',
#    'breed',
#    'of',
#    'dog',
#    'was',
#    'the',
#    '``',
#    'Little',
#    'Rascals',
#    "''",
#    'dog',
#    '?'],),
#  (['desc', 'What', 'are', 'the', 'living', 'conditions', 'in', 'Cuba', '?'],),
#  (['color', 'What', 'color', 'are', 'school', 'buses', '?'],),
#  (['other',
#    'What',
#    'is',
#    'the',
#    'oldest',
#    'website',
#    'on',
#    'the',
#    'Internet',
#    '?'],),
#  (['event', 'What', 'events', 'happened', 'January', '##', ',', '####', '?'],),
#  (['ind',
#    'What',
#    'explorers',
#    'followed',
#    'Columbus',
#    'to',
#    'the',
#    'Americas',
#    '?'],),
#  (['ind',
#    'Who',
#    'is',
#    'actress',
#    'Goldie',
#    'Hawn',
#    "'s",
#    'current',
#    'actor',
#    'boyfriend',
#    '?'],),
#  (['ind',
#    'Who',
#    'banned',
#    'Peter',
#    'Rose',
#    'from',
#    'baseball',
#    'for',
#    'betting',
#    'on',
#    'games',
#    '?'],),
#  (['def', 'What', 'are', 'the', 'seven', 'virtues', '?'],),
#  (['termeq',
#    'What',
#    'other',
#    'name',
#    'were',
#    'the',
#    '``',
#    'Little',
#    'Rascals',
#    "''",
#    'known',
#    'as',
#    '?'],),
#  (['date', 'When', 'was', 'the', 'San', 'Francisco', 'fire', '?'],),
#  (['dismed', 'What', 'is', 'a', 'fear', 'of', 'food', '?'],),
#  (['count',
#    'How',
#    'many',
#    'casinos',
#    'are',
#    'in',
#    'Atlantic',
#    'City',
#    ',',
#    'NJ',
#    '?'],),
#  (['date', 'What', 'year', 'did', 'the', 'Vietnam', 'War', 'end', '?'],),
#  (['ind',
#    'What',
#    'are',
#    'the',
#    'names',
#    'of',
#    'Richard',
#    'Nixon',
#    "'s",
#    'two',
#    'daughters',
#    '?'],),
#  (['word',
#    'What',
#    "'s",
#    'the',
#    'word',
#    'for',
#    'broken',
#    'glass',
#    'or',
#    'sharp',
#    'rocks',
#    'embedded',
#    'in',
#    'cement',
#    'on',
#    'top',
#    'of',
#    'a',
#    'wall',
#    '?'],),
#  (['count',
#    'What',
#    'is',
#    'the',
#    'chromosome',
#    'number',
#    'of',
#    'an',
#    'elephant',
#    '?'],),
#  (['gr',
#    'What',
#    'organization',
#    'was',
#    'founded',
#    'by',
#    'the',
#    'Rev.',
#    'Jerry',
#    'Falwell',
#    '?'],),
#  (['other',
#    'What',
#    "'s",
#    'the',
#    'longest',
#    'river',
#    'in',
#    'the',
#    'world',
#    '?'],),
#  (['food',
#    'Which',
#    'soft',
#    'drink',
#    'does',
#    'Madonna',
#    'advertise',
#    'for',
#    '?'],),
#  (['gr',
#    'What',
#    'company',
#    'is',
#    'being',
#    'bought',
#    'by',
#    'Yahoo',
#    'and',
#    'how',
#    'much',
#    'is',
#    'the',
#    'deal',
#    'worth',
#    '?'],),
#  (['date',
#    'When',
#    'was',
#    'Berlin',
#    "'s",
#    'Brandenburg',
#    'gate',
#    'erected',
#    '?'],),
#  (['count',
#    'How',
#    'many',
#    'double-word-score',
#    'spaces',
#    'are',
#    'there',
#    'on',
#    'a',
#    'Scrabble',
#    'Crossword',
#    'Game',
#    'board',
#    '?'],),
#  (['date',
#    'What',
#    'year',
#    'did',
#    'Germany',
#    'sign',
#    'its',
#    'nonaggression',
#    'pact',
#    'with',
#    'the',
#    'Soviet',
#    'Union',
#    '?'],),
#  (['mount',
#    'What',
#    'mountain',
#    'range',
#    'is',
#    'traversed',
#    'by',
#    'the',
#    'highest',
#    'railroad',
#    'in',
#    'the',
#    'world',
#    '?'],),
#  (['reason',
#    'Why',
#    'were',
#    'the',
#    'American',
#    'soldiers',
#    'in',
#    'WWI',
#    'called',
#    '``',
#    'Doughboys',
#    "''"],),
#  (['ind', 'Who', 'was', 'nicknamed', 'The', 'Little', 'Corporal', '?'],),
#  (['count', 'How', 'many', 'CDs', 'has', 'Garth', 'Brooks', 'sold', '?'],),
#  (['veh',
#    'Name',
#    'the',
#    'vessel',
#    'used',
#    'by',
#    'the',
#    'Atari',
#    'Force',
#    'in',
#    'the',
#    'DC',
#    'comics',
#    '.'],),
#  (['other',
#    'Where',
#    'are',
#    'the',
#    'leading',
#    'medical',
#    'groups',
#    'specializing',
#    'in',
#    'lung',
#    'diseases',
#    '?'],),
#  (['manner',
#    'How',
#    'can',
#    'I',
#    'find',
#    'online',
#    'spelling',
#    ',',
#    'and',
#    'punctuation',
#    'drills',
#    'for',
#    'my',
#    '#th',
#    'grader',
#    '?'],),
#  (['other', 'What', "'s", 'the', 'sacred', 'river', 'of', 'India', '?'],),
#  (['country',
#    'What',
#    'is',
#    'Stefan',
#    'Edberg',
#    "'s",
#    'native',
#    'country',
#    '?'],),
#  (['body',
#    'What',
#    'is',
#    'the',
#    'only',
#    'gland',
#    'in',
#    'humans',
#    'that',
#    'can',
#    'regenerate',
#    'itself',
#    '?'],),
#  (['count', 'How', 'many', 'Gutenberg', 'Bibles', 'are', 'there', '?'],),
#  (['country',
#    'Name',
#    'the',
#    'largest',
#    'country',
#    'in',
#    'South',
#    'America',
#    '.'],),
#  (['event',
#    'What',
#    'astronomical',
#    'phenomenon',
#    'takes',
#    'place',
#    'in',
#    'Jan.',
#    '####',
#    '?'],),
#  (['desc',
#    'What',
#    'information',
#    'can',
#    'you',
#    'get',
#    'me',
#    'on',
#    'Fairground',
#    'Park',
#    'in',
#    'St.',
#    'Louis'],),
#  (['ind',
#    'What',
#    'was',
#    'American',
#    'folk',
#    'hero',
#    'John',
#    'Chapman',
#    "'s",
#    'nickname',
#    '?'],),
#  (['desc',
#    'What',
#    'is',
#    'the',
#    'difference',
#    'between',
#    'a',
#    'median',
#    'and',
#    'a',
#    'mean',
#    '?'],),
#  (['cremat',
#    'What',
#    'was',
#    'the',
#    'top',
#    'box',
#    'office',
#    'movie',
#    'in',
#    'April',
#    '####',
#    '?'],),
#  (['reason', 'What', 'makes', 'thunder', '?'],),
#  (['ind',
#    'What',
#    'author',
#    'did',
#    'photographer',
#    'Yousuf',
#    'Karsh',
#    'call',
#    '``',
#    'the',
#    'shiest',
#    'man',
#    'I',
#    'ever',
#    'met',
#    "''",
#    '?'],),
#  (['other',
#    'Which',
#    'is',
#    'the',
#    'largest',
#    'clock',
#    ',',
#    'diameter',
#    'wise',
#    ',',
#    'in',
#    'Europe',
#    '?'],),
#  (['plant', 'What', 'plant', 'is', 'rum', 'made', 'from', '?'],),
#  (['country', 'What', 'country', 'are', 'Godiva', 'chocolates', 'from', '?'],),
#  (['ind', 'Name', 'the', 'poet', 'of', 'the', 'poem', 'which', 'begins'],),
#  (['food',
#    'Which',
#    'condiment',
#    'was',
#    'once',
#    'sold',
#    'as',
#    'a',
#    'patent',
#    'medicine',
#    '?'],),
#  (['state',
#    'What',
#    'U.S.',
#    'state',
#    'records',
#    'the',
#    'least',
#    'rainfall',
#    '?'],),
#  (['reason',
#    'Why',
#    'did',
#    'the',
#    'world',
#    'enter',
#    'a',
#    'global',
#    'depression',
#    'in',
#    '####',
#    '?'],),
#  (['def', 'What', 'was', 'archy', ',', 'and', 'mehitabel', '?'],),
#  (['city',
#    'What',
#    'Texas',
#    'city',
#    'got',
#    'its',
#    'name',
#    'from',
#    'the',
#    'Spanish',
#    'for',
#    '``',
#    'yellow',
#    "''",
#    '?'],),
#  (['substance',
#    'What',
#    'are',
#    'the',
#    'chemicals',
#    'used',
#    'in',
#    'glowsticks',
#    '?'],),
#  (['country',
#    'What',
#    'country',
#    'did',
#    'the',
#    'Nile',
#    'River',
#    'originate',
#    'in',
#    '?'],),
#  (['color', 'What', 'color', 'are', 'tennis', 'balls', '?'],),
#  (['ind',
#    'What',
#    'barroom',
#    'judge',
#    'called',
#    'himself',
#    'The',
#    'Law',
#    'West',
#    'of',
#    'the',
#    'Pecos',
#    '?'],),
#  (['desc',
#    'What',
#    'excuse',
#    'did',
#    'the',
#    'NATO',
#    'people',
#    'give',
#    'for',
#    'hitting',
#    'the',
#    'Chinese',
#    'embassy',
#    '?'],),
#  (['ind',
#    'Who',
#    'was',
#    'President',
#    'of',
#    'Costa',
#    'Rica',
#    'in',
#    '####',
#    '?'],),
#  (['sport',
#    'What',
#    'sports',
#    'event',
#    'is',
#    'Meyer',
#    'Wolfsheim',
#    'supposed',
#    'to',
#    'have',
#    'fixed',
#    'in',
#    'The',
#    'Great',
#    'Gatsby',
#    '?'],),
#  (['country',
#    'What',
#    'country',
#    'has',
#    'the',
#    'best',
#    'defensive',
#    'position',
#    'in',
#    'the',
#    'board',
#    'game',
#    'Diplomacy',
#    '?'],),
#  (['country',
#    'What',
#    'two',
#    'countries',
#    'share',
#    'the',
#    'Khyber',
#    'Pass',
#    '?'],),
#  (['ind',
#    'Who',
#    'was',
#    'chairman',
#    'of',
#    'the',
#    'Senate',
#    'select',
#    'committee',
#    'that',
#    'tried',
#    'to',
#    'get',
#    'to',
#    'the',
#    'bottom',
#    'of',
#    'Watergate',
#    '?'],),
#  (['desc',
#    'What',
#    'is',
#    'the',
#    'origin',
#    'of',
#    'the',
#    'surname',
#    'of',
#    'Braun',
#    '?'],),
#  (['sport',
#    'What',
#    'card',
#    'game',
#    'has',
#    'variations',
#    'called',
#    'Canfield',
#    ',',
#    'Klondike',
#    'and',
#    'Spider',
#    '?'],),
#  (['def', 'What', 'is', 'Australia', 'Day', '?'],),
#  (['animal',
#    'What',
#    'mammal',
#    'of',
#    'North',
#    'America',
#    'is',
#    'the',
#    'world',
#    "'s",
#    'longest-lived',
#    'for',
#    'its',
#    'size',
#    '?'],),
#  (['def', 'What', 'was', 'the', 'Chivington', 'Massacre', '?'],),
#  (['ind',
#    'What',
#    'actor',
#    'starred',
#    'in',
#    '####',
#    "'s",
#    'Blue',
#    'Lagoon',
#    ',',
#    '####',
#    "'s",
#    'The',
#    'Pirate',
#    'Movie',
#    'and',
#    '####',
#    "'s",
#    'A',
#    'Night',
#    'in',
#    'Heaven',
#    '?'],),
#  (['count',
#    'How',
#    'many',
#    'home',
#    'runs',
#    'did',
#    'Lou',
#    'Gehrig',
#    'have',
#    'during',
#    'his',
#    'career',
#    '?'],),
#  (['city',
#    'In',
#    'what',
#    'city',
#    'is',
#    'the',
#    'headquarters',
#    'of',
#    'Sinn',
#    'Fein',
#    '?'],),
#  (['other',
#    'Where',
#    'can',
#    'I',
#    'find',
#    'information',
#    'on',
#    'George',
#    'Bush',
#    '?'],),
#  (['ind', 'Who', 'is', 'the', 'voice', 'of', 'Miss', 'Piggy', '?'],),
#  (['termeq',
#    'What',
#    'is',
#    'the',
#    'dialogue',
#    'circle',
#    'in',
#    'cartoons',
#    'called',
#    '?'],),
#  (['def',
#    'What',
#    'does',
#    'the',
#    'word',
#    'camaro',
#    'mean',
#    ',',
#    'from',
#    'the',
#    'GM',
#    'car',
#    'the',
#    'Camaro',
#    '?'],),
#  (['ind',
#    'Who',
#    'replaced',
#    'Bert',
#    'Parks',
#    'as',
#    'the',
#    'host',
#    'of',
#    'The',
#    'Miss',
#    'America',
#    'Pageant',
#    '?'],),
#  (['count',
#    'How',
#    'many',
#    'boys',
#    'play',
#    'the',
#    'game',
#    'in',
#    'Winslow',
#    'Homer',
#    "'s",
#    '####',
#    'painting',
#    'Snap',
#    'the',
#    'Whip',
#    '?'],),
#  (['def', 'What', 'is', 'the', 'AIM-##C', 'Phoenix', '?'],),
#  (['date', 'When', 'are', 'sheep', 'shorn', '?'],),
#  (['sport',
#    'What',
#    'sport',
#    'is',
#    'Chris',
#    'Jogis',
#    'a',
#    'top',
#    'player',
#    'of',
#    '?'],),
#  (['other',
#    'What',
#    "'s",
#    'the',
#    'second-largest',
#    'island',
#    'in',
#    'the',
#    'world',
#    '?'],),
#  (['def', 'What', 'is', 'the', 'definition', 'of', 'low', 'island', '?'],),
#  (['date', 'What', 'century', 'does', 'Captain', 'Video', 'live', 'in', '?'],),
#  (['other',
#    'What',
#    'types',
#    'of',
#    'water',
#    'pollution',
#    'are',
#    'there',
#    '?'],),
#  (['count',
#    'How',
#    'many',
#    'astronauts',
#    'manned',
#    'each',
#    'Project',
#    'Mercury',
#    'flight',
#    '?'],),
#  (['food',
#    'What',
#    'soft',
#    'drink',
#    'would',
#    'provide',
#    'me',
#    'with',
#    'the',
#    'biggest',
#    'intake',
#    'of',
#    'caffeine',
#    '?'],),
#  (['other',
#    'What',
#    "'s",
#    'the',
#    'name',
#    'of',
#    'a',
#    'golf',
#    'course',
#    'in',
#    'Myrtle',
#    'Beach',
#    '?'],),
#  (['event',
#    'What',
#    'are',
#    'some',
#    'of',
#    'the',
#    'significant',
#    'historical',
#    'events',
#    'of',
#    'the',
#    '####s',
#    '?'],),
#  (['cremat',
#    'Name',
#    'the',
#    'only',
#    'extant',
#    'trilogy',
#    'of',
#    'classical',
#    'Greek',
#    'plays',
#    '.'],),
#  (['other', 'Where', 'is', 'Logan', 'Airport', '?'],),
#  (['desc',
#    'What',
#    'is',
#    'the',
#    'difference',
#    'between',
#    'Neoclassical',
#    'art',
#    'and',
#    'Romanticism',
#    'art',
#    '?'],),
#  (['ind',
#    'Who',
#    'was',
#    'the',
#    'first',
#    'person',
#    'inducted',
#    'into',
#    'the',
#    'U.S.',
#    'Swimming',
#    'Hall',
#    'of',
#    'Fame',
#    '?'],),
#  (['ind',
#    'What',
#    'golfer',
#    'has',
#    'been',
#    'called',
#    'Ohio',
#    'Fats',
#    'and',
#    'Blobbo',
#    '?'],),
#  (['ind',
#    'Who',
#    'murdered',
#    'Leno',
#    'and',
#    'Rosemary',
#    'LaBianca',
#    'on',
#    'August',
#    '#'],),
#  (['money',
#    'What',
#    'is',
#    'the',
#    'average',
#    'cost',
#    'for',
#    'four',
#    'years',
#    'of',
#    'medical',
#    'school',
#    '?'],),
#  (['other',
#    'What',
#    'does',
#    'God',
#    'create',
#    'in',
#    'the',
#    'first',
#    'sentence',
#    'of',
#    'the',
#    'Bible',
#    '?'],),
#  (['ind',
#    'Which',
#    'of',
#    'the',
#    'following',
#    'men',
#    'was',
#    'not',
#    'married',
#    'to',
#    'Rita',
#    'Hayworth',
#    '?'],),
#  (['money',
#    'What',
#    'is',
#    'the',
#    'current',
#    'ticket',
#    'fare',
#    'from',
#    'from',
#    'Cairo',
#    'to',
#    'Barbados',
#    '?'],),
#  (['exp',
#    'What',
#    'does',
#    'NN',
#    'O',
#    '``',
#    'mean',
#    'when',
#    'used',
#    'as',
#    'a',
#    'prefix',
#    'in',
#    'Irish',
#    'surnames',
#    '?'],),
#  (['manner', 'How', 'do', 'you', 'find', 'oxidation', 'numbers', '?'],),
#  (['state',
#    'What',
#    'is',
#    'the',
#    'state',
#    'nickname',
#    'of',
#    'Mississippi',
#    '?'],),
#  (['reason',
#    'What',
#    'is',
#    'Black',
#    'Hills',
#    ',',
#    'South',
#    'Dakota',
#    'most',
#    'famous',
#    'for',
#    '?'],),
#  (['cremat',
#    'What',
#    '####',
#    'boob',
#    'tube',
#    'bomb',
#    'took',
#    'astronauts',
#    'back',
#    'to',
#    'prehistoric',
#    'times',
#    '?'],),
#  (['count',
#    'How',
#    'many',
#    'students',
#    'attend',
#    'the',
#    'University',
#    'of',
#    'Massachusetts',
#    '?'],),
#  (['ind',
#    'Who',
#    'said',
#    ',',
#    '``',
#    'I',
#    'shall',
#    'return',
#    '.',
#    "''",
#    'during',
#    'World',
#    'War',
#    'Two',
#    '?'],),
#  (['event', 'What', 'holidays', 'are', 'celebrated', 'in', 'Ireland', '?'],),
#  (['ind',
#    'Who',
#    'portrayed',
#    'Etta',
#    'Place',
#    ',',
#    'companion',
#    'to',
#    'Butch',
#    'Cassidey',
#    'and',
#    'the',
#    'Sundance',
#    'Kid',
#    '?'],),
#  (['def', 'What', 'are', 'the', 'Greek', 'numerals', '?'],),
#  (['other',
#    'What',
#    "'s",
#    'the',
#    'name',
#    'of',
#    'the',
#    'temple',
#    'that',
#    'is',
#    'located',
#    'near',
#    'the',
#    'capital',
#    'city',
#    'of',
#    'Laos',
#    '?'],),
#  (['dismed', 'What', 'is', 'a', 'fear', 'of', 'sleep', '?'],),
#  (['sport',
#    'What',
#    'auto',
#    'race',
#    'was',
#    'Wilbur',
#    'Reed',
#    'the',
#    'first',
#    'to',
#    'win',
#    'three',
#    'times',
#    '?'],),
#  (['animal',
#    'What',
#    'are',
#    'the',
#    'most',
#    'common',
#    'breeding',
#    'birds',
#    'in',
#    'the',
#    'U.S.',
#    '?'],),
#  (['event',
#    'What',
#    'was',
#    'organized',
#    'as',
#    'a',
#    'Confederate',
#    'veterans',
#    "'",
#    'social',
#    'club',
#    'in',
#    'Pulaski',
#    ',',
#    'in',
#    'Tennessee',
#    ',',
#    'in',
#    '####',
#    '?'],),
#  (['manner',
#    'How',
#    'do',
#    'you',
#    'look',
#    'up',
#    'criminal',
#    'records',
#    'on',
#    'the',
#    'Internet',
#    '?'],),
#  (['other',
#    'Where',
#    'is',
#    'the',
#    'actress',
#    ',',
#    'Marion',
#    'Davies',
#    ',',
#    'buried',
#    '?'],),
#  (['desc',
#    'What',
#    'is',
#    'an',
#    'example',
#    'of',
#    'an',
#    'actual',
#    'case',
#    'of',
#    'using',
#    'the',
#    'Fourteenth',
#    'Amendment',
#    '?'],),
#  (['ind', 'Who', 'was', 'the', 'Charlie', 'perfume', 'woman', '?'],),
#  (['ind',
#    'Who',
#    'portrayed',
#    '``',
#    'Rosanne',
#    'Rosanna-Dana',
#    "''",
#    'on',
#    'the',
#    'television',
#    'show',
#    '``',
#    'Saturday',
#    'Night',
#    'Live',
#    "''",
#    '?'],)]

# %%
X_p, y_p = [], []
for pair in zip(X,y):
    X_p.append(prepare_sequence(pair[0], word2index).view(1, -1))
    y_p.append(Variable(LongTensor([target2index[pair[1]]])).view(1, -1))
    
data_p = list(zip(X_p, y_p))
random.shuffle(data_p)

train_data = data_p[: int(len(data_p) * 0.9)]
test_data = data_p[int(len(data_p) * 0.9):]

# %%
train_data[:5]
# Out:
# [(tensor([[1636,  194, 2435, 2003, 1130, 1607,   45,  532, 1918, 2270, 1607, 2335,
#            2521]], device='cuda:0'),
#   tensor([[1]], device='cuda:0')),
#  (tensor([[ 898, 2067,  192, 2740, 1537, 1783,  170, 1490, 1931,  292, 1384, 2740,
#            2291, 2521]], device='cuda:0'),
#   tensor([[4]], device='cuda:0')),
#  (tensor([[ 843, 2067,   51,  263,  463, 1065, 2270, 2740,  289, 1759, 2159, 1384,
#            1592, 2521]], device='cuda:0'),
#   tensor([[2]], device='cuda:0')),
#  (tensor([[ 843, 2067, 1064, 1968,  811,  917, 2738, 1759,  811, 1384, 2740, 1251,
#            2521]], device='cuda:0'),
#   tensor([[2]], device='cuda:0')),
#  (tensor([[ 782, 2067, 2126, 2740, 2193, 1759, 1921, 2521]], device='cuda:0'),
#   tensor([[5]], device='cuda:0'))]

# %%
import gensim

# %%
model = gensim.models.KeyedVectors.load_word2vec_format('./data/GoogleNews-vectors-negative300.bin', binary=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-54ed894b9b41> in <module>
# ----> 1 model = gensim.models.KeyedVectors.load_word2vec_format('./data/GoogleNews-vectors-negative300.bin', binary=True)
#
# C:\Anaconda3\envs\pytouch\lib\site-packages\gensim\models\keyedvectors.py in load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype)
#    1547         return _load_word2vec_format(
#    1548             cls, fname, fvocab=fvocab, binary=binary, encoding=encoding, unicode_errors=unicode_errors,
# -> 1549             limit=limit, datatype=datatype)
#    1550
#    1551     @classmethod
#
# C:\Anaconda3\envs\pytouch\lib\site-packages\gensim\models\utils_any2vec.py in _load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, binary_chunk_size)
#     275     with utils.open(fname, 'rb') as fin:
#     276         header = utils.to_unicode(fin.readline(), encoding=encoding)
# --> 277         vocab_size, vector_size = (int(x) for x in header.split())  # throws for invalid file format
#     278         if limit:
#     279             vocab_size = min(vocab_size, limit)
#
# C:\Anaconda3\envs\pytouch\lib\site-packages\gensim\models\utils_any2vec.py in <genexpr>(.0)
#     275     with utils.open(fname, 'rb') as fin:
#     276         header = utils.to_unicode(fin.readline(), encoding=encoding)
# --> 277         vocab_size, vector_size = (int(x) for x in header.split())  # throws for invalid file format
#     278         if limit:
#     279             vocab_size = min(vocab_size, limit)
#
# ValueError: invalid literal for int() with base 10: 'version'
