# %% [markdown]
# # AUTOGRAD
# - 자동 미분??

# %%
import torch

# %% [markdown]
# - .requires_grad 속성을 True 로 설정하면, 그 tensor에서 이뤄진 모든 연산들을 추적(track)하기 시작

# %%
x = torch.ones(2,2, requires_grad=True)
print(x)
# Out:
# tensor([[1., 1.],
#         [1., 1.]], requires_grad=True)

# %%
y = x + 2
print(y)
# Out:
# tensor([[3., 3.],
#         [3., 3.]], grad_fn=<AddBackward0>)

# %%
print(y.grad_fn)
# Out:
# <AddBackward0 object at 0x000001B5E0323E48>

# %%
z = y * y * 3
out = z.mean()

print(z, out)
# Out:
# tensor([[27., 27.],
#         [27., 27.]], grad_fn=<MulBackward0>) tensor(27., grad_fn=<MeanBackward0>)

# %%
out.backward()

# %% [markdown]
# - out에 대한 역전파 진행
# - out -> z -> y -> x
# ![image.png](attachment:image.png)

# %%
print(x.grad)
# Out:
# tensor([[4.5000, 4.5000],
#         [4.5000, 4.5000]])

# %%
print(x)
# Out:
# tensor([[1., 1.],
#         [1., 1.]], requires_grad=True)
